# %%
#pip install selenium

# %%
import pandas as pd
import numpy as np

# %%
from selenium import webdriver
import pandas as pd
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
import time

import warnings
warnings.filterwarnings('ignore')

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
driver = "./chromedriver.exe" #remember substitute this for your driver path
driver = webdriver.Chrome(ChromeDriverManager().install(),options = opciones)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\patri\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache

# %%
urlbase = 'https://nomadlist.com/'
driver.get(urlbase)

# %%
#base=driver.find_element_by_tag_name('ul')

# %%
#driver.find_elements_by_tag_name('li')[4].get_attribute('data-slug')

# %%
# scroll , codigo javascript
count=1
while count<150:
    try:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(2)
        count +=1
    except:
        break

# %%
cities=[]
for elemento in driver.find_elements_by_tag_name('li'):
    cities.append(elemento.get_attribute('data-slug'))

# %%
cities.pop(0)

# %%
cities.remove('{slug}')

# %%
len(cities)

# %%
print(cities)

# %%
# scroll , codigo javascript
driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
time.sleep(2)

# %%
score=driver.find_element_by_css_selector('body > div.modal.item.show.loaded > ajaxloaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-ranking.show > table > tbody > tr:nth-child(30) > td.key').text
score

# %%
cities=['ericeira', 'lisbon', 'miami', 'gran-canaria', 'budapest', 'austin', 'porto', 'buenos-aires', 'tbilisi', 'chiang-mai', 'sofia', 'warsaw', 'bangkok', 'belgrade', 'istanbul', 'phuket', 'madeira', 'ko-pha-ngan', 'da-nang', 'mexico-city', 'prague', 'cape-town', 'seoul', 'singapore', 'toronto', 'timisoara', 'berlin', 'stockholm', 'valencia', 'split', 'kuala-lumpur', 'sao-paulo', 'canggu', 'krakow', 'bengaluru', 'penang', 'atlanta', 'wroclaw', 'playa-del-carmen', 'zagreb', 'bucharest', 'yerevan', 'antalya', 'melbourne', 'honolulu', 'auckland', 'cluj', 'tenerife', 'sydney', 'ljubljana', 'florianopolis', 'vancouver', 'madrid', 'medellin', 'taipei', 'novi-sad', 'london', 'las-vegas', 'brasov', 'los-angeles', 'ubud', 'munich', 'copenhagen', 'athens', 'barcelona', 'rio-de-janeiro', 'lagos-algarve', 'new-york-city', 'tallinn', 'ho-chi-minh-city', 'denver', 'vienna', 'cancun', 'washington', 'boston', 'kotor', 'san-francisco', 'wellington', 'amsterdam', 'tampa', 'thessaloniki', 'coimbra', 'hamburg', 'hong-kong', 'portland', 'bansko', 'fuerteventura', 'manila', 'vilnius', 'plovdiv', 'portimao', 'dresden', 'quebec-city', 'chicago', 'johannesburg', 'davao', 'dallas', 'taghazout', 'san-miguel-de-allende', 'dubrovnik', 'quito', 'constanta', 'tulum', 'puerto-escondido', 'lima', 'tucson', 'brno', 'szczecin', 'chatham', 'braga', 'azores', 'chisinau', 'havana', 'el-gouna', 'seville', 'cebu', 'ottawa', 'willemstad', 'guanajuato', 'shanghai', 'queretaro', 'minneapolis', 'yangon', 'ploiesti', 'gdansk', 
ia', 'sariwon', 'constantine', 'ko-samui', 'cabarete', 'yichang', 'anyang', 'interlaken', 'beersheba', 'sargodha', 'daejeon', 'st-gallen', 'rawalpindi', 'san-pedro', 'nampo', 'dakar', 'peshawar', 'xiangtan', 'haifa', 'tangshan', 'bahawalpur', 'mykonos', 'victoria-seychelles', 'kenosha', 'kabul', 'zibo', 'managua', 'leon', 'handan', 'king-edward-point', 'islamabad', 'santa-teresa', 'ashgabat', 'tamarindo', 'faisalabad', 'multan', 'benghazi', 'tegucigalpa', 'gujranwala', 'ko-tao', 'bellevue', 'vatican-city', 'basra', 'yantai', 'sialkot', 'cayenne', 'martinique', 'san-pedro-sula', 'kralendijk', 'port-moresby', 'copan', 'ajaccio', 'ahvaz', 'khartoum', 'kuwait-city', 'hamamatsu', 'damascus', 'djibouti', 'changsha', 'bangui', 'bay-islands', 'yangzhou', 'jeddah', 'mecca', 'monrovia', 'noumea', 'tabarana-do-norte', 'ndjamena', 'kyiv', 'moscow', 'lviv', 'minsk', 'odessa', 'ivano-frankivsk', 'saint-petersburg', 'ufa', 'kharkiv', 'krasnodar', 'krasnoyarsk', 'dnipro', 'krivoy-rog', 'izhevsk', 'chelyabinsk', 'saratov', 'omsk', 'yekaterinburg', 'kaliningrad', 'ulyanovsk', 'obninsk', 'rostov-on-don', 'samara', 'novosibirsk', 'tomsk', 'vladivostok', 'kazan', 'nizhny']

# %%
urlbase = 'https://nomadlist.com/'
info_ciudades = []
for i in cities:
    driver.get(urlbase + i)
    score=['Ciudad']
    score_desc=[f'{i}']
    cont=1
    while True:
        try:
            score.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > ajaxloaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-ranking.show > table > tbody > tr:nth-child({cont}) > td.key').text)
            score_desc.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > ajaxloaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-ranking.show > table > tbody > tr:nth-child({cont}) > td.value > div > div').text)
            cont +=1
        except:
            print('ya!')
            break
    dic_ciudad = dict(zip(score,score_desc))
    info_ciudades.append(dic_ciudad)
# Out:
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!
# ya!

# %%
info_ciudades
# Out:
# [{'Ciudad': 'ericeira',
#   '⭐️ Total score': '4.7/5 (Rank #2)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '😙 Affordable: $2,293 / mo',
#   '📡 Internet': '🏎 Fast: 46Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🌞 Nice: 18°C (feels 18°C)',
#   '💦 Humidity (now)': '😊 Comfy: 88%',
#   '💨 Air quality (now)': '🌱 Great: 31 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 32 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Great',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Low: $1,646 / mo',
#   '❤️ Liked by members': '👍80% liked it 👎20% disliked it',
#   '🙊 English speaking*': 'Great',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Healthcare*': 'Good',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Great',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Good',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Great',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'lisbon',
#   '⭐️ Total score': '4.72/5 (Rank #1)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '😙 Affordable: $2,398 / mo',
#   '📡 Internet': '🏎 Fast: 35Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🌞 Perfect: 24°C (feels 24°C)',
#   '💦 Humidity (now)': '😊 Comfy: 65%',
#   '💨 Air quality (now)': '🌱 Great: 15 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 31 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Low: $1,646 / mo',
#   '❤️ Liked by members': '👍88% liked it 👎12% disliked it',
#   '🙊 English speaking*': 'Great',
#   '😤 People density': '🧘\u200d♀️ Low density: 6k ppl/km² (12x12m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Bad',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'miami',
#   '⭐️ Total score': '4.69/5 (Rank #3)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '🧐 Too expensive: $4,922 / mo',
#   '📡 Internet': '🏎 Fast: 46Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🌞 Perfect: 27°C (feels 31°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 79%',
#   '💨 Air quality (now)': '🌱 Great: 27 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 33 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Good',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very high: $4,817 / mo',
#   '❤️ Liked by members': '👍88% liked it 👎13% disliked it',
#   '🙊 English speaking*': 'Good',
#   '😤 People density': '🧘\u200d♀️ Low density: 4k ppl/km² (15x15m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Great',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'gran-canaria',
#   '⭐️ Total score': '4.58/5 (Rank #4)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '😙 Affordable: $1,720 / mo',
#   '📡 Internet': '🏎 Fast: 35Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Perfect: 24°C (feels 24°C)',
#   '💦 Humidity (now)': '😊 Comfy: 80%',
#   '💨 Air quality (now)': '😐 Moderate: 78 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Mediocre: $2,225 / mo',
#   '❤️ Liked by members': '👍100% liked it 👎0% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Healthcare*': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Bad',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'budapest',
#   '⭐️ Total score': '4.56/5 (Rank #5)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '😙 Affordable: $1,102 / mo',
#   '📡 Internet': '🏎 Fast: 32Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Perfect: 22°C (feels 22°C)',
#   '💦 Humidity (now)': '😊 Comfy: 59%',
#   '💨 Air quality (now)': '🌱 Great: 34 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 34 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very low: $1,075 / mo',
#   '❤️ Liked by members': '👍90% liked it 👎10% disliked it',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Good',
#   '😁 Friendly to foreigners': 'Okay',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'austin',
#   '⭐️ Total score': '4.49/5 (Rank #7)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '🧐 Pricey: $3,857 / mo',
#   '📡 Internet': '🚀 Super fast: 90Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🥵 Too hot: 33°C (feels 46°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 79%',
#   '💨 Air quality (now)': '🌱 Great: 30 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 38 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Good',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very high: $4,817 / mo',
#   '❤️ Liked by members': '👍95% liked it 👎5% disliked it',
#   '🙊 English speaking*': 'Great',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Good'},
#  {'Ciudad': 'porto',
#   '⭐️ Total score': '4.53/5 (Rank #6)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '😙 Affordable: $2,279 / mo',
#   '📡 Internet': '🏎 Fast: 38Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Nice: 19°C (feels 20°C)',
#   '💦 Humidity (now)': '😊 Comfy: 83%',
#   '💨 Air quality (now)': '🌱 Great: 38 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 10 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Low: $1,646 / mo',
#   '❤️ Liked by members': '👍86% liked it 👎14% disliked it',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'buenos-aires',
#   '⭐️ Total score': '4.33/5 (Rank #18)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '😝 Cheap: $895 / mo',
#   '📡 Internet': '🙂 Good: 6Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Nice: 20°C (feels 21°C)',
#   '💦 Humidity (now)': '😊 Comfy: 82%',
#   '💨 Air quality (now)': '😐 Moderate: 80 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 24 US AQI',
#   '👌 Safety': 'Okay',
#   '👮\u200d♀️ Lack of crime*': 'Okay',
#   '🤝 Lack of racism*': 'Good',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very low: $1,037 / mo',
#   '❤️ Liked by members': '👍89% liked it 👎11% disliked it',
#   '🙊 English speaking*': 'Okay',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'tbilisi',
#   '⭐️ Total score': '4.49/5 (Rank #8)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,327 / mo',
#   '📡 Internet': '🏎 Fast: 13Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🥶 A bit cold: 16°C (feels 16°C)',
#   '💦 Humidity (now)': '😊 Comfy: 59%',
#   '💨 Air quality (now)': '🌱 Great: 19 US AQI',
#   '💨 Air quality (annual)': '😷 Unhealthy for some: 150 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very low: $304 / mo',
#   '❤️ Liked by members': '👍95% liked it 👎5% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Okay',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Bad',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Bad',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'chiang-mai',
#   '⭐️ Total score': '4.43/5 (Rank #11)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😝 Cheap: $957 / mo',
#   '📡 Internet': '🏎 Fast: 25Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🥵 Too hot: 30°C (feels 38°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 84%',
#   '💨 Air quality (now)': '🌱 Great: 15 US AQI',
#   '💨 Air quality (annual)': '🌱 Good: 58 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $493 / mo',
#   '❤️ Liked by members': '👍89% liked it 👎11% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '😤 People density': '🧘\u200d♀️ Low density: 3k ppl/km² (17x17m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Okay',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Okay',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'sofia',
#   '⭐️ Total score': '4.44/5 (Rank #10)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,333 / mo',
#   '📡 Internet': '🏎 Fast: 25Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Nice: 18°C (feels 19°C)',
#   '💦 Humidity (now)': '😊 Comfy: 65%',
#   '💨 Air quality (now)': '🌱 Great: 26 US AQI',
#   '💨 Air quality (annual)': '😐 Moderate: 84 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very low: $622 / mo',
#   '❤️ Liked by members': '👍96% liked it 👎4% disliked it',
#   '🙊 English speaking*': 'Okay',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Bad',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Great',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Okay',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'warsaw',
#   '⭐️ Total score': '4.47/5 (Rank #9)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '😙 Affordable: $1,766 / mo',
#   '📡 Internet': '🏎 Fast: 19Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🌞 Nice: 18°C (feels 18°C)',
#   '💦 Humidity (now)': '😊 Comfy: 43%',
#   '💨 Air quality (now)': '🌱 Great: 50 US AQI',
#   '💨 Air quality (annual)': '🌱 Good: 56 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very low: $1,028 / mo',
#   '❤️ Liked by members': '👍91% liked it 👎9% disliked it',
#   '🙊 English speaking*': 'Good',
#   '😤 People density': '🧘\u200d♀️ Low density: 4k ppl/km² (15x15m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'bangkok',
#   '⭐️ Total score': '4.43/5 (Rank #12)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,287 / mo',
#   '📡 Internet': '🏎 Fast: 28Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Perfect: 29°C (feels 38°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 96%',
#   '💨 Air quality (now)': '🌱 Good: 55 US AQI',
#   '💨 Air quality (annual)': '🌱 Good: 55 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $493 / mo',
#   '❤️ Liked by members': '👍87% liked it 👎13% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '😤 People density': '🧘\u200d♀️ Low density: 5k ppl/km² (14x14m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Great',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Okay',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Good',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'belgrade',
#   '⭐️ Total score': '4.3/5 (Rank #19)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '😙 Affordable: $1,508 / mo',
#   '📡 Internet': '🏎 Fast: 30Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Perfect: 22°C (feels 22°C)',
#   '💦 Humidity (now)': '😊 Comfy: 63%',
#   '💨 Air quality (now)': '😐 Moderate: 90 US AQI',
#   '💨 Air quality (annual)': '😷 Unhealthy for some: 106 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $452 / mo',
#   '❤️ Liked by members': '👍88% liked it 👎13% disliked it',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Healthcare*': 'Okay',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'istanbul',
#   '⭐️ Total score': '4.42/5 (Rank #13)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,136 / mo',
#   '📡 Internet': '🙂 Good: 7Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🥶 A bit cold: 17°C (feels 17°C)',
#   '💦 Humidity (now)': '💦 Damp: 71%',
#   '💨 Air quality (now)': '🌱 Great: 26 US AQI',
#   '💨 Air quality (annual)': '😷 Unhealthy for some: 110 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $905 / mo',
#   '❤️ Liked by members': '👍82% liked it 👎18% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '😤 People density': '🤨 Busy: 10k ppl/km² (10x10m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Bad',
#   '👩 Female friendly': 'Bad',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'phuket',
#   '⭐️ Total score': '4.3/5 (Rank #20)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,237 / mo',
#   '📡 Internet': '🏎 Fast: 26Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🥵 Too hot: 30°C (feels 40°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 91%',
#   '💨 Air quality (now)': '🌱 Good: 53 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 42 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $493 / mo',
#   '❤️ Liked by members': '👍85% liked it 👎15% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '😤 People density': '🧘\u200d♀️ Sprawling: 1k ppl/km² (39x39m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Good',
#   '😁 Friendly to foreigners': 'Okay',
#   '🗯 Freedom of speech*': 'Okay',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Good',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'madeira',
#   '⭐️ Total score': '4.28/5 (Rank #21)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '😙 Affordable: $2,110 / mo',
#   '📡 Internet': '🏎 Fast: 39Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Perfect: 22°C (feels 22°C)',
#   '💦 Humidity (now)': '😊 Comfy: 70%',
#   '💨 Air quality (now)': '🌱 Good: 62 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Low: $1,646 / mo',
#   '❤️ Liked by members': '👍100% liked it 👎0% disliked it',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Okay',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Healthcare*': 'Good',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Great',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'ko-pha-ngan',
#   '⭐️ Total score': '4.25/5 (Rank #22)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,033 / mo',
#   '📡 Internet': '🏎 Fast: 24Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🌞 Perfect: 29°C (feels 36°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 87%',
#   '💨 Air quality (now)': '🌱 Good: 53 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $493 / mo',
#   '❤️ Liked by members': '👍100% liked it 👎0% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Healthcare*': 'Good',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Bad',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Okay',
#   '👩 Female friendly': 'Great',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'da-nang',
#   '⭐️ Total score': '4.18/5 (Rank #30)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,020 / mo',
#   '📡 Internet': '🙂 Good: 6Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🥵 Too hot: 30°C (feels 41°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 94%',
#   '💨 Air quality (now)': '🌱 Great: 45 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 36 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Low',
#   '💰 Income level*': 'Very low: $181 / mo',
#   '❤️ Liked by members': '👍87% liked it 👎13% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Healthcare*': 'Okay',
#   '😄 Happiness*': 'Bad',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Good',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Bad',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'mexico-city',
#   '⭐️ Total score': '4.34/5 (Rank #16)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,510 / mo',
#   '📡 Internet': '🏎 Fast: 11Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Perfect: 27°C (feels 27°C)',
#   '💦 Humidity (now)': '😊 Comfy: 43%',
#   '💨 Air quality (now)': '🌱 Good: 59 US AQI',
#   '💨 Air quality (annual)': '🌱 Good: 55 US AQI',
#   '👌 Safety': 'Okay',
#   '👮\u200d♀️ Lack of crime*': 'Bad',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $704 / mo',
#   '❤️ Liked by members': '👍95% liked it 👎5% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '😤 People density': '🧘\u200d♀️ Low density: 9k ppl/km² (11x11m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Healthcare*': 'Okay',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Bad',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'prague',
#   '⭐️ Total score': '4.23/5 (Rank #24)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '🙂 Okay: $2,595 / mo',
#   '📡 Internet': '🏎 Fast: 33Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🌞 Perfect: 22°C (feels 22°C)',
#   '💦 Humidity (now)': '😊 Comfy: 60%',
#   '💨 Air quality (now)': '🌱 Good: 74 US AQI',
#   '💨 Air quality (annual)': '🌱 Good: 56 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Low: $1,534 / mo',
#   '❤️ Liked by members': '👍91% liked it 👎9% disliked it',
#   '🙊 English speaking*': 'Good',
#   '😤 People density': '🧘\u200d♀️ Low density: 4k ppl/km² (15x15m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Great',
#   '🌈 LGBTQ+ friendly': 'Good',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'cape-town',
#   '⭐️ Total score': '4.41/5 (Rank #14)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,782 / mo',
#   '📡 Internet': '🙂 Good: 6Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🥶 A bit cold: 17°C (feels 17°C)',
#   '💦 Humidity (now)': '💦 Damp: 89%',
#   '💨 Air quality (now)': '🌱 Great: 30 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 16 US AQI',
#   '👌 Safety': 'Okay',
#   '👮\u200d♀️ Lack of crime*': 'Very bad',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $425 / mo',
#   '❤️ Liked by members': '👍94% liked it 👎6% disliked it',
#   '🙊 English speaking*': 'Great',
#   '😤 People density': '🧘\u200d♀️ Low density: 4k ppl/km² (16x16m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Bad',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Bad',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'seoul',
#   '⭐️ Total score': '4.21/5 (Rank #26)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '😙 Affordable: $2,215 / mo',
#   '📡 Internet': '🏎 Fast: 26Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Perfect: 23°C (feels 23°C)',
#   '💦 Humidity (now)': '🌵 Too dry: 30%',
#   '💨 Air quality (now)': '🌱 Good: 57 US AQI',
#   '💨 Air quality (annual)': '🌱 Good: 75 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Mediocre: $2,315 / mo',
#   '❤️ Liked by members': '👍87% liked it 👎13% disliked it',
#   '🙊 English speaking*': 'Okay',
#   '😤 People density': '😤 Dense: 17k ppl/km² (8x8m)',
#   '🚶 Walkability': 'Bad',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Great',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Great',
#   '🌈 LGBTQ+ friendly': 'Okay',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'singapore',
#   '⭐️ Total score': '4.33/5 (Rank #17)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '🧐 Pricey: $3,429 / mo',
#   '📡 Internet': '🚀 Super fast: 60Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🥵 Too hot: 31°C (feels 44°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 91%',
#   '💨 Air quality (now)': '🌱 Great: 17 US AQI',
#   '💨 Air quality (annual)': '🌱 Good: 54 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Good',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very high: $4,401 / mo',
#   '❤️ Liked by members': '👍94% liked it 👎6% disliked it',
#   '🙊 English speaking*': 'Great',
#   '😤 People density': '🤨 Busy: 11k ppl/km² (9x9m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Great',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Okay',
#   '🗯 Freedom of speech*': 'Bad',
#   '👩 Female friendly': 'Great',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'toronto',
#   '⭐️ Total score': '4.2/5 (Rank #27)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '🧐 Pricey: $3,514 / mo',
#   '📡 Internet': '🏎 Fast: 19Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🥶 A bit cold: 16°C (feels 16°C)',
#   '💦 Humidity (now)': '😊 Comfy: 43%',
#   '💨 Air quality (now)': '🌱 Great: 38 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 35 US AQI',
#   '👌 Safety': 'Okay',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Great',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'High: $3,513 / mo',
#   '❤️ Liked by members': '👍79% liked it 👎21% disliked it',
#   '🙊 English speaking*': 'Great',
#   '😤 People density': '🧘\u200d♀️ Low density: 4k ppl/km² (15x15m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Great',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Great',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'timisoara',
#   '⭐️ Total score': '4.16/5 (Rank #31)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,290 / mo',
#   '📡 Internet': '🏎 Fast: 39Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Nice: 21°C (feels 21°C)',
#   '💦 Humidity (now)': '😊 Comfy: 71%',
#   '💨 Air quality (now)': '🌱 Great: 8 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 24 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very low: $787 / mo',
#   '❤️ Liked by members': '👍100% liked it 👎0% disliked it',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Great',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'berlin',
#   '⭐️ Total score': '4.15/5 (Rank #32)',
#   '👍 Quality of life score': 'Great',
#   '👶 Family score': 'Good',
#   '💵 Cost': '🧐 Pricey: $3,995 / mo',
#   '📡 Internet': '🏎 Fast: 24Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🌞 Perfect: 24°C (feels 24°C)',
#   '💦 Humidity (now)': '😊 Comfy: 55%',
#   '💨 Air quality (now)': '🌱 Good: 53 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 23 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Good',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'High: $3,538 / mo',
#   '❤️ Liked by members': '👍86% liked it 👎14% disliked it',
#   '🙊 English speaking*': 'Great',
#   '😤 People density': '🧘\u200d♀️ Low density: 4k ppl/km² (16x16m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Great',
#   '👩 Female friendly': 'Great',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Good'},
#  {'Ciudad': 'stockholm',
#   '⭐️ Total score': '4.11/5 (Rank #36)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '🧐 Pricey: $3,576 / mo',
#   '📡 Internet': '🏎 Fast: 34Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🥶 Too cold: 14°C (feels 13°C)',
#   '💦 Humidity (now)': '😊 Comfy: 62%',
#   '💨 Air quality (now)': '🌱 Great: 15 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 9 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Good',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very high: $4,224 / mo',
#   '❤️ Liked by members': '👍79% liked it 👎21% disliked it',
#   '🙊 English speaking*': 'Great',
#   '😤 People density': '🧘\u200d♀️ Low density: 5k ppl/km² (14x14m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Great',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Great',
#   '👩 Female friendly': 'Great',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'valencia',
#   '⭐️ Total score': '4.23/5 (Rank #23)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '🙂 Okay: $2,804 / mo',
#   '📡 Internet': '🏎 Fast: 39Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Nice: 21°C (feels 21°C)',
#   '💦 Humidity (now)': '😊 Comfy: 66%',
#   '💨 Air quality (now)': '🌱 Great: 34 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 50 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Mediocre: $2,225 / mo',
#   '❤️ Liked by members': '👍91% liked it 👎9% disliked it',
#   '🙊 English speaking*': 'Okay',
#   '😤 People density': '🧘\u200d♀️ Low density: 6k ppl/km² (13x13m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Great',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'split',
#   '⭐️ Total score': '4.11/5 (Rank #37)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '🧐 Pricey: $3,168 / mo',
#   '📡 Internet': '🏎 Fast: 12Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🌞 Perfect: 22°C (feels 22°C)',
#   '💦 Humidity (now)': '😊 Comfy: 64%',
#   '💨 Air quality (now)': '🌱 Great: 4 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 10 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very low: $1,013 / mo',
#   '❤️ Liked by members': '👍94% liked it 👎6% disliked it',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Okay',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Bad',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Bad',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Okay',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'kuala-lumpur',
#   '⭐️ Total score': '4.13/5 (Rank #35)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,280 / mo',
#   '📡 Internet': '🏎 Fast: 11Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🥵 Too hot: 31°C (feels 44°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 91%',
#   '💨 Air quality (now)': '🌱 Good: 52 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 39 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $792 / mo',
#   '❤️ Liked by members': '👍80% liked it 👎20% disliked it',
#   '🙊 English speaking*': 'Okay',
#   '😤 People density': '🧘\u200d♀️ Low density: 4k ppl/km² (17x17m)',
#   '🚶 Walkability': 'Okay',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Bad',
#   '👩 Female friendly': 'Bad',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'sao-paulo',
#   '⭐️ Total score': '4.19/5 (Rank #29)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,399 / mo',
#   '📡 Internet': '🙂 Good: 9Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🌞 Perfect: 22°C (feels 22°C)',
#   '💦 Humidity (now)': '😊 Comfy: 84%',
#   '💨 Air quality (now)': '😐 Moderate: 76 US AQI',
#   '💨 Air quality (annual)': '😷 Unhealthy for some: 103 US AQI',
#   '👌 Safety': 'Okay',
#   '👮\u200d♀️ Lack of crime*': 'Very bad',
#   '🤝 Lack of racism*': 'Good',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $721 / mo',
#   '❤️ Liked by members': '👍95% liked it 👎5% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Great',
#   '📶 Free WiFi in city': 'Bad',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Good',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Okay',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'canggu',
#   '⭐️ Total score': '4.36/5 (Rank #15)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,450 / mo',
#   '📡 Internet': '🏎 Fast: 25Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🥵 Too hot: 30°C (feels 40°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 91%',
#   '💨 Air quality (now)': '🌱 Good: 72 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Good',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $298 / mo',
#   '❤️ Liked by members': '👍83% liked it 👎17% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '😤 People density': '🧘\u200d♀️ Low density: 8k ppl/km² (11x11m)',
#   '🚶 Walkability': 'Okay',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Healthcare*': 'Bad',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Okay',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Good',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'krakow',
#   '⭐️ Total score': '4.08/5 (Rank #39)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '😙 Affordable: $1,783 / mo',
#   '📡 Internet': '🏎 Fast: 35Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🌞 Nice: 19°C (feels 20°C)',
#   '💦 Humidity (now)': '😊 Comfy: 54%',
#   '💨 Air quality (now)': '🌱 Great: 50 US AQI',
#   '💨 Air quality (annual)': '😷 Unhealthy for some: 139 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very low: $1,028 / mo',
#   '❤️ Liked by members': '👍94% liked it 👎6% disliked it',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Okay',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Okay',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'bengaluru',
#   '⭐️ Total score': '4.14/5 (Rank #34)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😝 Cheap: $714 / mo',
#   '📡 Internet': '🏎 Fast: 37Mbps (avg)',
#   '😝 Fun': 'Bad',
#   '⛅️ Temperature (now)': '🌞 Perfect: 27°C (feels 30°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 76%',
#   '💨 Air quality (now)': '🌱 Great: 38 US AQI',
#   '💨 Air quality (annual)': '😐 Moderate: 92 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'Low',
#   '💰 Income level*': 'Very low: $142 / mo',
#   '❤️ Liked by members': '👍100% liked it 👎0% disliked it',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Bad',
#   '🍸 Nightlife': 'Bad',
#   '📶 Free WiFi in city': 'Bad',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Bad',
#   '😁 Friendly to foreigners': 'Okay',
#   '🗯 Freedom of speech*': 'Okay',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'penang',
#   '⭐️ Total score': '4/5 (Rank #42)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,044 / mo',
#   '📡 Internet': '🏎 Fast: 13Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🥵 Too hot: 30°C (feels 41°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 93%',
#   '💨 Air quality (now)': '🌱 Good: 63 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Good',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $792 / mo',
#   '❤️ Liked by members': '👍71% liked it 👎29% disliked it',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Great',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Bad',
#   '👩 Female friendly': 'Great',
#   '🌈 LGBTQ+ friendly': 'Okay',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'atlanta',
#   '⭐️ Total score': '3.98/5 (Rank #46)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Good',
#   '💵 Cost': '🧐 Pricey: $3,014 / mo',
#   '📡 Internet': '🏎 Fast: 44Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Nice: 21°C (feels 21°C)',
#   '💦 Humidity (now)': '😊 Comfy: 64%',
#   '💨 Air quality (now)': '🌱 Good: 62 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 36 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Good',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very high: $4,817 / mo',
#   '❤️ Liked by members': '👍100% liked it 👎0% disliked it',
#   '🙊 English speaking*': 'Great',
#   '😤 People density': '🧘\u200d♀️ Sprawling: 1k ppl/km² (38x38m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'wroclaw',
#   '⭐️ Total score': '4.03/5 (Rank #40)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,878 / mo',
#   '📡 Internet': '🏎 Fast: 19Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Nice: 21°C (feels 21°C)',
#   '💦 Humidity (now)': '😊 Comfy: 64%',
#   '💨 Air quality (now)': '🌱 Good: 52 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 43 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very low: $1,028 / mo',
#   '❤️ Liked by members': '👍100% liked it 👎0% disliked it',
#   '🙊 English speaking*': 'Okay',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'playa-del-carmen',
#   '⭐️ Total score': '4.14/5 (Rank #33)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,677 / mo',
#   '📡 Internet': '🙂 Good: 6Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🥵 Too hot: 30°C (feels 39°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 88%',
#   '💨 Air quality (now)': '🌱 Good: 61 US AQI',
#   '👌 Safety': 'Okay',
#   '👮\u200d♀️ Lack of crime*': 'Bad',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $704 / mo',
#   '❤️ Liked by members': '👍86% liked it 👎14% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Healthcare*': 'Okay',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Bad',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'zagreb',
#   '⭐️ Total score': '4.01/5 (Rank #41)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $2,021 / mo',
#   '📡 Internet': '🏎 Fast: 14Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🌞 Perfect: 22°C (feels 22°C)',
#   '💦 Humidity (now)': '😊 Comfy: 73%',
#   '💨 Air quality (now)': '🌱 Great: 5 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 15 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very low: $1,013 / mo',
#   '❤️ Liked by members': '👍100% liked it 👎0% disliked it',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'bucharest',
#   '⭐️ Total score': '3.99/5 (Rank #45)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,582 / mo',
#   '📡 Internet': '🚀 Super fast: 55Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Nice: 18°C (feels 18°C)',
#   '💦 Humidity (now)': '😊 Comfy: 63%',
#   '💨 Air quality (now)': '🌱 Great: 21 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 31 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very low: $787 / mo',
#   '❤️ Liked by members': '👍81% liked it 👎19% disliked it',
#   '🙊 English speaking*': 'Okay',
#   '😤 People density': '🧘\u200d♀️ Low density: 8k ppl/km² (11x11m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Healthcare*': 'Okay',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Bad',
#   '😁 Friendly to foreigners': 'Okay',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'yerevan',
#   '⭐️ Total score': '3.94/5 (Rank #56)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,518 / mo',
#   '📡 Internet': '🙂 Good: 7Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🥶 A bit cold: 15°C (feels 15°C)',
#   '💦 Humidity (now)': '💦 Damp: 72%',
#   '💨 Air quality (now)': '🌱 Great: 39 US AQI',
#   '💨 Air quality (annual)': '🌱 Good: 59 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $301 / mo',
#   '❤️ Liked by members': '👍86% liked it 👎14% disliked it',
#   '🙊 English speaking*': 'Okay',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Bad',
#   '😄 Happiness*': 'Bad',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Great',
#   '🖥 Places to work from': 'Great',
# ...
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'Very low',
#   '💰 Income level*': 'Very low: $30 / mo',
#   '🙊 English speaking*': 'Okay',
#   '🚶 Walkability': 'Okay',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Healthcare*': 'Bad',
#   '😄 Happiness*': 'Bad',
#   '🍸 Nightlife': 'Bad',
#   '📶 Free WiFi in city': 'Bad',
#   '🖥 Places to work from': 'Bad',
#   '❄️ A/C or heating': 'Bad',
#   '😁 Friendly to foreigners': 'Bad',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Bad',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'erlangen',
#   '⭐️ Total score': '2.86/5 (Rank #987)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '🧐 Pricey: $3,743 / mo',
#   '📡 Internet': '🏎 Fast: 24Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🌞 Perfect: 24°C (feels 24°C)',
#   '💦 Humidity (now)': '😊 Comfy: 68%',
#   '💨 Air quality (now)': '🌱 Great: 41 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'High: $3,538 / mo',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Bad',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Bad',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Okay',
#   '🗯 Freedom of speech*': 'Great',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'minca',
#   '⭐️ Total score': '2.86/5 (Rank #988)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Bad',
#   '💵 Cost': '😙 Affordable: $1,392 / mo',
#   '📡 Internet': '🏎 Fast: 13Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🌞 Perfect: 24°C (feels 24°C)',
#   '💦 Humidity (now)': '😊 Comfy: 100%',
#   '💨 Air quality (now)': '🌱 Good: 59 US AQI',
#   '👌 Safety': 'Bad',
#   '👮\u200d♀️ Lack of crime*': 'Very bad',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $484 / mo',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Okay',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Healthcare*': 'Okay',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '🗯 Freedom of speech*': 'Okay',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'male',
#   '⭐️ Total score': '2.86/5 (Rank #989)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Bad',
#   '💵 Cost': '🧐 Pricey: $3,179 / mo',
#   '📡 Internet': '😡 Slow: 2Mbps (avg)',
#   '😝 Fun': 'Great',
#   '⛅️ Temperature (now)': '🥵 Too hot: 30°C (feels 39°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 86%',
#   '💨 Air quality (now)': '🌱 Good: 53 US AQI',
#   '💨 Air quality (annual)': '🌱 Good: 68 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🎓 Education level*': 'Low',
#   '💰 Income level*': 'Very low: $736 / mo',
#   '🙊 English speaking*': 'Okay',
#   '😤 People density': '😤 Dense: 23k ppl/km² (7x7m)',
#   '🚶 Walkability': 'Great',
#   '🚦 Traffic safety*': 'Okay',
#   '🍸 Nightlife': 'Bad',
#   '📶 Free WiFi in city': 'Bad',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Okay',
#   '👩 Female friendly': 'Bad',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'giza',
#   '⭐️ Total score': '3.14/5 (Rank #571)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Bad',
#   '💵 Cost': '😙 Affordable: $1,146 / mo',
#   '📡 Internet': '😡 Slow: 3Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🥵 Too hot: 30°C (feels 31°C)',
#   '💦 Humidity (now)': '😊 Comfy: 47%',
#   '💨 Air quality (now)': '🌱 Great: 50 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 33 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $235 / mo',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Bad',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Bad',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Okay',
#   '🗯 Freedom of speech*': 'Bad',
#   '👩 Female friendly': 'Bad',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'stanley',
#   '⭐️ Total score': '2.86/5 (Rank #991)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Good',
#   '💵 Cost': '🧐 Too expensive: $4,133 / mo',
#   '📡 Internet': '🤬 Unusably slow: 0.00Mbps (avg)',
#   '😝 Fun': 'Bad',
#   '⛅️ Temperature (now)': '🥶 Too cold: 7°C (feels 4°C)',
#   '💦 Humidity (now)': '💦 Damp: 78%',
#   '💨 Air quality (now)': '🌱 Great: 17 US AQI',
#   '👌 Safety': 'Great',
#   '🤝 Lack of racism*': 'Good',
#   '💰 Income level*': 'Very high: $4,733 / mo',
#   '🙊 English speaking*': 'Great',
#   '🚶 Walkability': 'Bad',
#   '🚦 Traffic safety*': 'Okay',
#   '🍸 Nightlife': 'Bad',
#   '📶 Free WiFi in city': 'Bad',
#   '🖥 Places to work from': 'Bad',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Okay',
#   '👩 Female friendly': 'Great',
#   '🌈 LGBTQ+ friendly': 'Good',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'sayulita',
#   '⭐️ Total score': '2.86/5 (Rank #992)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $2,370 / mo',
#   '📡 Internet': '🏎 Fast: 11Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🌞 Perfect: 26°C (feels 29°C)',
#   '💦 Humidity (now)': '😊 Comfy: 87%',
#   '💨 Air quality (now)': '🌱 Great: 45 US AQI',
#   '👌 Safety': 'Okay',
#   '👮\u200d♀️ Lack of crime*': 'Bad',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $704 / mo',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Okay',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Healthcare*': 'Okay',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Bad',
#   '🖥 Places to work from': 'Bad',
#   '❄️ A/C or heating': 'Bad',
#   '😁 Friendly to foreigners': 'Bad',
#   '🗯 Freedom of speech*': 'Bad',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'marseille',
#   '⭐️ Total score': '2.86/5 (Rank #993)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '🧐 Pricey: $3,487 / mo',
#   '📡 Internet': '🏎 Fast: 24Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🌞 Nice: 21°C (feels 21°C)',
#   '💦 Humidity (now)': '😊 Comfy: 72%',
#   '💨 Air quality (now)': '🌱 Great: 43 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 33 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Mediocre: $3,069 / mo',
#   '🙊 English speaking*': 'Okay',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Good',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Great',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'sapporo',
#   '⭐️ Total score': '2.86/5 (Rank #994)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '🙂 Okay: $2,810 / mo',
#   '📡 Internet': '🏎 Fast: 26Mbps (avg)',
#   '😝 Fun': 'Good',
#   '⛅️ Temperature (now)': '🌞 Nice: 21°C (feels 21°C)',
#   '💦 Humidity (now)': '😊 Comfy: 50%',
#   '💨 Air quality (now)': '🌱 Great: 34 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 46 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'High: $3,220 / mo',
#   '🙊 English speaking*': 'Bad',
#   '😤 People density': '🧘\u200d♀️ Low density: 5k ppl/km² (14x14m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Good',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Bad',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Bad',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Okay',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'maracay',
#   '⭐️ Total score': '2.86/5 (Rank #995)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Bad',
#   '💵 Cost': '😙 Affordable: $1,945 / mo',
#   '📡 Internet': '🤬 Unusably slow: 1Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🌞 Perfect: 27°C (feels 31°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 82%',
#   '💨 Air quality (now)': '🌱 Great: 30 US AQI',
#   '👌 Safety': 'Bad',
#   '👮\u200d♀️ Lack of crime*': 'Very bad',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $769 / mo',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Bad',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Bad',
#   '📶 Free WiFi in city': 'Okay',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Bad',
#   '😁 Friendly to foreigners': 'Okay',
#   '🗯 Freedom of speech*': 'Okay',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'xiamen',
#   '⭐️ Total score': '2.86/5 (Rank #996)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Bad',
#   '💵 Cost': '😙 Affordable: $2,044 / mo',
#   '📡 Internet': '🤬 Unusably slow: 0.00Mbps (avg)',
#   '😝 Fun': 'Bad',
#   '⛅️ Temperature (now)': '🌞 Perfect: 24°C (feels 24°C)',
#   '💦 Humidity (now)': '😊 Comfy: 100%',
#   '💨 Air quality (now)': '🌱 Great: 42 US AQI',
#   '💨 Air quality (annual)': '🌱 Good: 71 US AQI',
#   '👌 Safety': 'Great',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $677 / mo',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Healthcare*': 'Good',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Bad',
#   '📶 Free WiFi in city': 'Bad',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Okay',
#   '🗯 Freedom of speech*': '',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'hangzhou',
#   '⭐️ Total score': '2.86/5 (Rank #997)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '😙 Affordable: $1,264 / mo',
#   '📡 Internet': '🤬 Unusably slow: 1Mbps (avg)',
#   '😝 Fun': 'Bad',
#   '⛅️ Temperature (now)': '🌞 Nice: 21°C (feels 21°C)',
#   '💦 Humidity (now)': '😊 Comfy: 95%',
#   '💨 Air quality (now)': '😐 Moderate: 78 US AQI',
#   '💨 Air quality (annual)': '😐 Moderate: 99 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Great',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'Mediocre',
#   '💰 Income level*': 'Very low: $677 / mo',
#   '🙊 English speaking*': 'Bad',
#   '😤 People density': '🧘\u200d♀️ Low density: 6k ppl/km² (13x13m)',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Okay',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Great',
#   '🖥 Places to work from': 'Bad',
#   '❄️ A/C or heating': 'Good',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': '',
#   '👩 Female friendly': 'Good',
#   '🌈 LGBTQ+ friendly': 'Okay',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'omaha',
#   '⭐️ Total score': '2.86/5 (Rank #998)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '🧐 Pricey: $3,496 / mo',
#   '📡 Internet': '🚀 Super fast: 57Mbps (avg)',
#   '😝 Fun': 'Bad',
#   '⛅️ Temperature (now)': '🌞 Perfect: 28°C (feels 30°C)',
#   '💦 Humidity (now)': '😊 Comfy: 65%',
#   '💨 Air quality (now)': '😐 Moderate: 85 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 33 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Good',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'Very high: $4,817 / mo',
#   '🙊 English speaking*': 'Great',
#   '🚶 Walkability': 'Okay',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Hospitals': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Bad',
#   '🖥 Places to work from': 'Good',
#   '❄️ A/C or heating': 'Great',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Good',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'bruges',
#   '⭐️ Total score': '2.86/5 (Rank #999)',
#   '👍 Quality of life score': 'Good',
#   '👶 Family score': 'Okay',
#   '💵 Cost': '🧐 Too expensive: $4,030 / mo',
#   '📡 Internet': '🏎 Fast: 33Mbps (avg)',
#   '😝 Fun': 'Okay',
#   '⛅️ Temperature (now)': '🌞 Nice: 18°C (feels 18°C)',
#   '💦 Humidity (now)': '😊 Comfy: 71%',
#   '💨 Air quality (now)': '🌱 Great: 30 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 33 US AQI',
#   '👌 Safety': 'Good',
#   '👮\u200d♀️ Lack of crime*': 'Good',
#   '🤝 Lack of racism*': 'Okay',
#   '🎓 Education level*': 'High',
#   '💰 Income level*': 'High: $3,433 / mo',
#   '🙊 English speaking*': 'Good',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Good',
#   '🚦 Traffic safety*': 'Okay',
#   '🏥 Healthcare*': 'Great',
#   '😄 Happiness*': 'Good',
#   '🍸 Nightlife': 'Good',
#   '📶 Free WiFi in city': 'Good',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Okay',
#   '😁 Friendly to foreigners': 'Good',
#   '🗯 Freedom of speech*': 'Great',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Great',
#   '🎅 Startup Score': 'Okay'},
#  {'Ciudad': 'vientiane',
#   '⭐️ Total score': '3.15/5 (Rank #544)',
#   '👍 Quality of life score': 'Okay',
#   '👶 Family score': 'Bad',
#   '💵 Cost': '😝 Cheap: $795 / mo',
#   '📡 Internet': '🤬 Unusably slow: 1Mbps (avg)',
#   '😝 Fun': 'Bad',
#   '⛅️ Temperature (now)': '🥵 Too hot: 30°C (feels 40°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 91%',
#   '💨 Air quality (now)': '🌱 Great: 5 US AQI',
#   '💨 Air quality (annual)': '🌱 Great: 33 US AQI',
#   '👌 Safety': 'Okay',
#   '👮\u200d♀️ Lack of crime*': 'Okay',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'Low',
#   '💰 Income level*': 'Very low: $195 / mo',
#   '❤️ Liked by members': '👍75% liked it 👎25% disliked it',
#   '🙊 English speaking*': 'Bad',
#   '🚶 Walkability': 'Great',
#   '✌️ Peace (no pol. conflict)': 'Okay',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Healthcare*': 'Bad',
#   '🍸 Nightlife': 'Bad',
#   '📶 Free WiFi in city': 'Bad',
#   '🖥 Places to work from': 'Great',
#   '❄️ A/C or heating': 'Bad',
#   '😁 Friendly to foreigners': 'Great',
#   '🗯 Freedom of speech*': 'Bad',
#   '👩 Female friendly': 'Okay',
#   '🌈 LGBTQ+ friendly': 'Okay',
#   '🎅 Startup Score': 'Bad'},
#  {'Ciudad': 'kisangani',
#   '⭐️ Total score': '2.86/5 (Rank #1001)',
#   '👍 Quality of life score': 'Bad',
#   '👶 Family score': 'Bad',
#   '💵 Cost': '😙 Affordable: $1,524 / mo',
#   '📡 Internet': '🤬 Unusably slow: 0.00Mbps (avg)',
#   '😝 Fun': 'Bad',
#   '⛅️ Temperature (now)': '🥵 Too hot: 30°C (feels 38°C)',
#   '💦 Humidity (now)': '🥵 Sweaty: 83%',
#   '💨 Air quality (now)': '😐 Moderate: 89 US AQI',
#   '👌 Safety': 'Bad',
#   '👮\u200d♀️ Lack of crime*': 'Bad',
#   '🤝 Lack of racism*': 'Bad',
#   '🎓 Education level*': 'Low',
#   '💰 Income level*': 'Very low: $43 / mo',
#   '🙊 English speaking*': 'Okay',
#   '🚶 Walkability': 'Bad',
#   '✌️ Peace (no pol. conflict)': 'Bad',
#   '🚦 Traffic safety*': 'Bad',
#   '🏥 Healthcare*': 'Bad',
#   '🍸 Nightlife': 'Okay',
#   '📶 Free WiFi in city': 'Bad',
#   '🖥 Places to work from': 'Bad',
#   '❄️ A/C or heating': 'Bad',
#   '😁 Friendly to foreigners': 'Okay',
#   '👩 Female friendly': 'Bad',
#   '🌈 LGBTQ+ friendly': 'Bad',
#   '🎅 Startup Score': 'Bad'},
#  ...]

# %%
df=pd.DataFrame(info_ciudades)
df
# Out:
#             Ciudad        ⭐️ Total score 👍 Quality of life score  \
# 0         ericeira       4.7/5 (Rank #2)                    Good
# 1           lisbon      4.72/5 (Rank #1)                    Good
# 2            miami      4.69/5 (Rank #3)                    Good
# 3     gran-canaria      4.58/5 (Rank #4)                    Good
# 4         budapest      4.56/5 (Rank #5)                    Good
# ...            ...                   ...                     ...
# 1340   novosibirsk  -0.05/5 (Rank #1350)                    Okay
# 1341         tomsk  -0.06/5 (Rank #1351)                    Okay
# 1342   vladivostok  -0.12/5 (Rank #1352)                    Okay
# 1343         kazan  -0.13/5 (Rank #1353)                    Okay
# 1344        nizhny  -0.22/5 (Rank #1354)                    Okay
#
#      👶 Family score                        💵 Cost            📡 Internet  \
# 0              Good     😙 Affordable: $2,293 / mo  🏎 Fast: 46Mbps (avg)
# 1              Good     😙 Affordable: $2,398 / mo  🏎 Fast: 35Mbps (avg)
# 2              Good  🧐 Too expensive: $4,922 / mo  🏎 Fast: 46Mbps (avg)
# 3              Good     😙 Affordable: $1,720 / mo  🏎 Fast: 35Mbps (avg)
#                            😤 People density 🏥 Hospitals
# 0                                       NaN         NaN
# 1     🧘‍♀️ Low density: 6k ppl/km² (12x12m)         Bad
# 2     🧘‍♀️ Low density: 4k ppl/km² (15x15m)       Great
# 3                                       NaN         NaN
# 4                                       NaN        Good
# ...                                     ...         ...
# 1340                                    NaN         Bad
# 1341                                    NaN       Great
# 1342                                    NaN         NaN
# 1343                                    NaN         Bad
# 1344    🧘‍♀️ Sprawling: 3k ppl/km² (18x18m)         NaN
#
# [1345 rows x 34 columns]

# %%
df.to_csv('./primer.csv')

# %%
nan_cols=df.isna().sum()
nan_cols
# Out:
# Ciudad                           0
# ⭐️ Total score                   0
# 👍 Quality of life score          0
# 👶 Family score                   0
# 💵 Cost                           0
# 📡 Internet                       0
# 😝 Fun                            5
# 👌 Safety                         0
# 👮‍♀️ Lack of crime*             19
# 🤝 Lack of racism*               70
# 🎓 Education level*              43
# 💰 Income level*                  0
# 🙊 English speaking*              1
# 🚶 Walkability                    0
# ✌️ Peace (no pol. conflict)     55
# 🚦 Traffic safety*                0
# 🏥 Healthcare*                  885
# 😄 Happiness*                    76
# 🍸 Nightlife                      2
# 📶 Free WiFi in city             16
# ❄️ A/C or heating              304
# 😁 Friendly to foreigners       293
# 🗯 Freedom of speech*            48
# 👩 Female friendly                0
# 🌈 LGBTQ+ friendly                0
# 🎅 Startup Score                  0
# 🏥 Hospitals                    522
# dtype: int64

# %%
df.drop(659,axis=0,inplace=True)
df.drop(1009,axis=0,inplace=True)
df.drop(1011,axis=0,inplace=True)
df.drop(1271,axis=0,inplace=True)

# %%
df.drop(columns=['⛅️ Temperature (now)','💦 Humidity (now)','💨 Air quality (now)','💨 Air quality (annual)','❤️ Liked by members','😤 People density','🖥 Places to work from'],inplace=True)

# %%
df['👮‍♀️ Lack of crime*'].value_counts()
# Out:
# Good        688
# Great       389
# Okay         92
# Bad          90
# Very bad     63
# Name: 👮‍♀️ Lack of crime*, dtype: int64

# %%
df['🖥 Places to work from']=df['🖥 Places to work from'].fillna('Unknown')

# %%
df['⭐️ Total score']=df['⭐️ Total score'].apply(lambda x : x.split('(')[0])

# %%
df3=df[df['👮‍♀️ Lack of crime*'].isnull()]
#planets[planets.mass.isnull()]
df3
# Out:
#                  Ciudad       ⭐️ Total score 👍 Quality of life score  \
# 117          willemstad   3.65/5 (Rank #122)                    Good
# 881             abidjan   2.94/5 (Rank #883)                    Okay
# 950              kirkuk   2.88/5 (Rank #952)                    Okay
# 989             stanley   2.86/5 (Rank #991)                    Okay
# 1000       yamoussoukro  2.85/5 (Rank #1002)                     Bad
# 1012          jamestown  2.85/5 (Rank #1014)                    Okay
# 1049       sulaymaniyah   2.8/5 (Rank #1051)                    Okay
# 1057              duhok   2.8/5 (Rank #1059)                    Okay
# 1092           laayoune  2.76/5 (Rank #1094)                    Okay
# 1138          gibraltar  2.71/5 (Rank #1141)                    Good
# 1167       saint-helier  2.68/5 (Rank #1170)                    Good
# 1183             nassau  2.66/5 (Rank #1186)                    Okay
# 1222     amundsen-scott  2.59/5 (Rank #1226)                    Okay
# 1223    mcmurdo-station  2.59/5 (Rank #1227)                    Okay
# 1229              erbil  2.58/5 (Rank #1233)                    Okay
# 1234        philipsburg  2.56/5 (Rank #1238)                    Okay
# 1278  king-edward-point  2.42/5 (Rank #1283)                    Okay
# 1290       vatican-city  2.34/5 (Rank #1296)                    Okay
# 1297         kralendijk  2.31/5 (Rank #1303)                    Okay
#
#      👶 Family score                             💵 Cost  \
# 117            Good          😙 Affordable: $2,079 / mo
# 881             Bad          😙 Affordable: $1,986 / mo
# 950             Bad          😙 Affordable: $1,768 / mo
# 989            Good       🧐 Too expensive: $4,133 / mo
# 1000            Bad          😙 Affordable: $2,308 / mo
# 1012           Good       🧐 Too expensive: $4,364 / mo
# 1049            Bad                🙂 Okay: $2,656 / mo
# 1057           Okay                🙂 Okay: $2,870 / mo
# 1092            Bad          😙 Affordable: $1,017 / mo
# 1138           Okay       🧐 Too expensive: $4,897 / mo
# 1167           Okay   😳 Way too expensive: $6,615 / mo
# 1183           Okay       🧐 Too expensive: $4,549 / mo
# 1222           Okay  😳 Way too expensive: $13,762 / mo
# 1223           Okay  😳 Way too expensive: $13,762 / mo
# 1229            Bad              🧐 Pricey: $3,143 / mo
# 1234           Okay       🧐 Too expensive: $4,504 / mo
# 1278           Okay  😳 Way too expensive: $10,562 / mo
# 1290           Okay       🧐 Too expensive: $4,708 / mo
# 1297           Okay   😳 Way too expensive: $5,510 / mo
#
#                            📡 Internet  😝 Fun  👌 Safety 👮‍♀️ Lack of crime*  \
# 117               🙂 Good: 9Mbps (avg)  Great      Okay                 NaN
# 881      🤬 Unusably slow: 1Mbps (avg)   Okay      Okay                 NaN
# 950      🤬 Unusably slow: 1Mbps (avg)    Bad  Very bad                 NaN
# 989   🤬 Unusably slow: 0.00Mbps (avg)    Bad     Great                 NaN
# 1000              🙂 Good: 7Mbps (avg)    Bad       Bad                 NaN
# 1012  🤬 Unusably slow: 0.00Mbps (avg)    Bad     Great                 NaN
# 1049     🤬 Unusably slow: 1Mbps (avg)   Good       Bad                 NaN
# 1057     🤬 Unusably slow: 1Mbps (avg)   Okay      Okay                 NaN
# 1092              🙂 Good: 8Mbps (avg)    Bad       Bad                 NaN
# 1138             🏎 Fast: 15Mbps (avg)   Okay      Okay                 NaN
# 1167             🏎 Fast: 30Mbps (avg)   Okay      Okay                 NaN
# 1183              😡 Slow: 5Mbps (avg)   Good      Okay                 NaN
# 1222  🤬 Unusably slow: 0.00Mbps (avg)   Okay      Good                 NaN
# 1223  🤬 Unusably slow: 0.00Mbps (avg)   Okay      Good                 NaN
# 1229              😡 Slow: 3Mbps (avg)    Bad       Bad                 NaN
# 1234              🙂 Good: 9Mbps (avg)   Okay       Bad                 NaN
# 1278  🤬 Unusably slow: 0.00Mbps (avg)    Bad     Great                 NaN
# 1290              🙂 Good: 7Mbps (avg)   Good      Okay                 NaN
# 1297              😡 Slow: 5Mbps (avg)   Good      Okay                 NaN
#
#      🤝 Lack of racism*  ... 😄 Happiness* 🍸 Nightlife 📶 Free WiFi in city  \
# 117               Okay  ...          NaN       Great                Good
# 881                NaN  ...          Bad        Good                Okay
# 950               Okay  ...          NaN         Bad                 Bad
# 989               Good  ...          NaN         Bad                 Bad
# 1000              Okay  ...          Bad         Bad                 Bad
# 1012              Okay  ...          NaN         Bad                 Bad
# 1049              Okay  ...          NaN        Okay                 Bad
# 1057              Okay  ...          NaN         Bad                 Bad
# 1092               Bad  ...          NaN         Bad                 Bad
# 1138              Okay  ...          NaN        Okay                 Bad
# 1167               NaN  ...          NaN         Bad                Good
# 1183              Okay  ...          NaN        Good                Okay
# 1222              Good  ...          NaN         Bad                Good
# 1223              Good  ...          NaN         Bad                Good
# 1229              Okay  ...          NaN         Bad                 Bad
# 1234              Okay  ...          NaN        Okay                Good
# 1278               Bad  ...          NaN         Bad                 Bad
# 1290              Okay  ...          NaN         Bad                Okay
# 1297              Okay  ...          NaN        Good                Okay
#
#      ❄️ A/C or heating 😁 Friendly to foreigners 🗯 Freedom of speech*  \
# 117               Good                    Great                  NaN
# 881               Okay                      Bad                  NaN
# 950                Bad                      Bad                  NaN
# 989               Okay                     Okay                  NaN
# 1000               Bad                      Bad                  NaN
# 1012               NaN                     Good                  NaN
# 1049               Bad                     Good                  NaN
# 1057              Okay                     Okay                  NaN
# 1092               Bad                      Bad                  NaN
# 1138              Okay                     Good                  NaN
# 1167               Bad                     Okay                  NaN
# 1183              Okay                     Good                  NaN
# 1222              Good                     Good                  NaN
# 1223              Good                     Good                  NaN
# 1229              Okay                     Good                  Bad
# 1234              Good                     Good                  NaN
# 1278               Bad                     Okay                  NaN
# 1290              Okay                      Bad                  NaN
# 1297              Okay                     Good                  NaN
#
#      👩 Female friendly 🌈 LGBTQ+ friendly 🎅 Startup Score 🏥 Hospitals
# 117               Good              Good            Okay         NaN
# 881                Bad               Bad             Bad         NaN
# 950                Bad               Bad             Bad         NaN
# 989              Great              Good            Okay         NaN
# 1000               Bad               Bad             Bad         NaN
# 1012              Okay              Good            Okay         NaN
# 1049               Bad               Bad             Bad         NaN
# 1057              Good               Bad             Bad         NaN
# 1092               Bad               Bad             Bad         NaN
# 1138              Good               Bad            Okay         NaN
# 1167              Okay             Great            Okay         NaN
# 1183              Okay              Okay            Okay        Okay
# 1222              Good             Great            Okay         NaN
# 1223              Good             Great            Okay         NaN
# 1229               Bad               Bad             Bad         NaN
# 1234              Okay               Bad            Okay         NaN
# 1278               Bad              Good             Bad         NaN
# 1290              Okay               Bad             Bad         NaN
# 1297              Okay              Okay             Bad         NaN
#
# [19 rows x 27 columns]

# %%
df
# Out:
#             Ciudad ⭐️ Total score 👍 Quality of life score 👶 Family score  \
# 0         ericeira         4.7/5                     Good           Good
# 1           lisbon        4.72/5                     Good           Good
# 2            miami        4.69/5                     Good           Good
# 3     gran-canaria        4.58/5                     Good           Good
# 4         budapest        4.56/5                     Good           Good
# ...            ...            ...                     ...            ...
# 1340   novosibirsk       -0.05/5                     Okay            Bad
# 1341         tomsk       -0.06/5                     Okay            Bad
# 1342   vladivostok       -0.12/5                     Okay            Bad
# 1343         kazan       -0.13/5                     Okay            Bad
# 1344        nizhny       -0.22/5                     Okay            Bad
#
#                             💵 Cost            📡 Internet  😝 Fun  \
# 0        😙 Affordable: $2,293 / mo  🏎 Fast: 46Mbps (avg)  Great
# 1        😙 Affordable: $2,398 / mo  🏎 Fast: 35Mbps (avg)  Great
# 2     🧐 Too expensive: $4,922 / mo  🏎 Fast: 46Mbps (avg)  Great
# 3        😙 Affordable: $1,720 / mo  🏎 Fast: 35Mbps (avg)   Good
# 4        😙 Affordable: $1,102 / mo  🏎 Fast: 32Mbps (avg)   Good
# ...                            ...                   ...    ...
# 1340     😙 Affordable: $1,476 / mo   🙂 Good: 9Mbps (avg)    Bad
# 1341     😙 Affordable: $1,789 / mo  🏎 Fast: 11Mbps (avg)    Bad
# 1342     😙 Affordable: $2,134 / mo   🙂 Good: 9Mbps (avg)    Bad
# 1343           🙂 Okay: $2,564 / mo  🏎 Fast: 11Mbps (avg)    Bad
# 1344           🙂 Okay: $2,910 / mo  🏎 Fast: 11Mbps (avg)    Bad
#
#                                  👌 Safety 👮‍♀️ Lack of crime*  \
# 0                                   Great               Great
# 1                                   Great               Great
# 2                                    Good                Good
# 3                                   Great               Great
# 4                                    Good                Good
# ...                                   ...                 ...
# 1340  🧨 Conflict / political instability*                 Bad
# 1341  🧨 Conflict / political instability*                 Bad
# 1342  🧨 Conflict / political instability*                 Bad
# 1343  🧨 Conflict / political instability*                 Bad
# 1344  🧨 Conflict / political instability*                 Bad
#
#      🤝 Lack of racism*  ... 🍸 Nightlife 📶 Free WiFi in city  \
# 0                Great  ...       Great               Great
# 1                 Okay  ...        Okay                Okay
# 2                 Good  ...       Great               Great
# 3                 Okay  ...        Good                Okay
# 4                  Bad  ...       Great                Good
# ...                ...  ...         ...                 ...
# 1340               Bad  ...        Okay                Okay
# 1341               Bad  ...         Bad                 Bad
# 1342               Bad  ...        Okay                 Bad
# 1343               Bad  ...        Okay                Good
# 1344               Bad  ...        Good                 Bad
#
#      🖥 Places to work from ❄️ A/C or heating 😁 Friendly to foreigners  \
# 0                    Great              Good                    Great
# 1                    Great              Okay                     Good
# 2                    Great             Great                    Great
# 3                    Great               Bad                     Good
# 4                    Great              Good                     Okay
# ...                    ...               ...                      ...
# 1340                 Great               Bad                     Okay
# 1341                 Great               Bad                     Good
# 1342                 Great               Bad                     Okay
# 1343                 Great              Okay                     Okay
# 1344                 Great               Bad                     Good
#
#      🗯 Freedom of speech* 👩 Female friendly 🌈 LGBTQ+ friendly 🎅 Startup Score  \
# 0                    Good             Great             Great            Okay
# 1                    Good              Good             Great            Okay
# 2                    Good              Good             Great            Okay
# 3                    Good              Good             Great            Okay
# 4                    Good              Good               Bad            Okay
# ...                   ...               ...               ...             ...
# 1340                  Bad              Okay               Bad             Bad
# 1341                  Bad              Okay               Bad             Bad
# 1342                  Bad              Okay               Bad             Bad
# 1343                  Bad               Bad               Bad             Bad
# 1344                  Bad              Okay               Bad             Bad
#
#      🏥 Hospitals
# 0            NaN
# 1            Bad
# 2          Great
# 3            NaN
# 4           Good
# ...          ...
# 1340         Bad
# 1341       Great
# 1342         NaN
# 1343         Bad
# 1344         NaN
#
# [1341 rows x 28 columns]
