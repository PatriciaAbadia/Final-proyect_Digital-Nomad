# %%
#pip install selenium

# %%
import pandas as pd
import numpy as np

# %%
from selenium import webdriver
import pandas as pd
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
import time

import warnings
warnings.filterwarnings('ignore')

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
driver = "./chromedriver.exe" #remember substitute this for your driver path
driver = webdriver.Chrome(ChromeDriverManager().install(),options = opciones)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\patri\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache

# %% [markdown]
# ### * La página es para todos las ciudades igual, en este caso quiero sacar el tiempo por ciudades y por meses. Parto del listado de ciudades sacadas anteriormente. Hay 4 ciudades en las que no funciona la página (san-jose-costa-rica, la-paz-mexico, cordoba-spain, victoria-seychelles), por lo que lo saco en varias partes (aparte de que tarda mucho en 'scrapearse'):

# %%
urlbase = 'https://nomadlist.com/weather/'
driver.get(urlbase)

# %%
cities=['ericeira', 'lisbon', 'miami', 'gran-canaria', 'budapest', 'austin', 'porto', 'buenos-aires', 'tbilisi', 'chiang-mai', 'sofia', 'warsaw', 'bangkok', 'belgrade', 'istanbul', 'phuket', 'madeira', 'ko-pha-ngan', 'da-nang', 'mexico-city', 'prague', 'cape-town', 'seoul', 'singapore', 'toronto', 'timisoara', 'berlin', 'stockholm', 'valencia', 'split', 'kuala-lumpur', 'sao-paulo', 'canggu', 'krakow', 'bengaluru', 'penang', 'atlanta', 'wroclaw', 'playa-del-carmen', 'zagreb', 'bucharest', 'yerevan', 'antalya', 'melbourne', 'honolulu', 'auckland', 'cluj', 'tenerife', 'sydney', 'ljubljana', 'florianopolis', 'vancouver', 'madrid', 'medellin', 'taipei', 'novi-sad', 'london', 'las-vegas', 'brasov', 'los-angeles', 'ubud', 'munich', 'copenhagen', 'athens', 'barcelona', 'rio-de-janeiro', 'lagos-algarve', 'new-york-city', 'tallinn', 'ho-chi-minh-city', 'denver', 'vienna', 'cancun', 'washington', 'boston', 'kotor', 'san-francisco', 'wellington', 'amsterdam', 'tampa', 'thessaloniki', 'coimbra', 'hamburg', 'hong-kong', 'portland', 'bansko', 'fuerteventura', 'manila', 'vilnius', 'plovdiv', 'portimao', 'dresden', 'quebec-city', 'chicago', 'johannesburg', 'davao', 'dallas', 'taghazout', 'san-miguel-de-allende', 'dubrovnik', 'quito', 'constanta', 'tulum', 'puerto-escondido', 'lima', 'tucson', 'brno', 'szczecin', 'chatham', 'braga', 'azores', 'chisinau', 'havana', 'el-gouna', 'seville', 'cebu', 'ottawa', 'willemstad', 'guanajuato', 'shanghai', 'queretaro', 'minneapolis', 'yangon', 'ploiesti', 'gdansk', 'riga', 'jeju-island', 'seattle', 'batumi', 'victoria', 'edmonton', 'cologne', 'paris', 'brussels', 'krabi', 'mumbai', 'luang-prabang', 'salt-lake-city', 'varna', 'siem-reap', 'sarajevo', 'poznan', 'skopje', 'tirana', 'perth', 'aveiro', 'bratislava', 'christchurch', 'hoi-an', 'almaty', 'porto-alegre', 'leip
rapid-city', 'fort-collins', 'verona', 'helena', 'kinshasa', 'portland-me', 'nanyang', 'zhengzhou', 'bilbao', 'belize-city', 'menlo-park', 'ithaca', 'monterey', 'savannah', 'karachi', 'aurangabad', 'mosul', 'basse-terre', 'san-juan-del-sur', 'oceanside', 'coeur-dalene', 'accra', 'vista', 'chandigarh', 'corvallis', 'alesund', 'san-mateo', 'saint-helier', 'tengzhou', 'dammam', 'monaco', 'salento', 'vineland', 'kaesong', 'basel', 'port-orange', 'kuta', 'darwin', 'medina', 'biarritz', 'haarlem', 'luoyang', 'banff', 'nassau', 'indio', 'quetta', 'jerusalem', 'luxembourg', 'dushanbe', 'cody', 'petaluma', 'leeuwarden', 'jiaxing', 'sparks', 'libreville', 'road-town', 'plantation', 'bonita-springs', 'verdi', 'urumqi', 'missoula', 'incline-village', 'shijiazhuang', 'doha', 'knoxville', 'cali', 'port-vila', 'zhucheng', 'zhuzhou', 'jinan', 'napa', 'salem-ma', 'xiangyang', 'monza', 'lagos', 'george-town', 'ferrara', 'puerto-viejo', 'baoding', 'canton', 'oshkosh', 'mogadishu', 'amundsen-scott', 'mcmurdo-station', 'chongjin', 'sharjah', 'zandvoort', 'arendal', 'gulfport', 'erbil', 'hamhung', 'turin', 'tuscaloosa', 'hamilton', 'philipsburg', 'baghdad', 'isfahan', 'lucca', 'lausanne', 'lahore', 'muscat', 'weifang', 'san-angelo', 'lugano', 'cathedral-city', 'riyadh', 'palm-desert', 'zaria', 'charlotte-amalie', 'liberia', 'sariwon', 'constantine', 'ko-samui', 'cabarete', 'yichang', 'anyang', 'interlaken', 'beersheba', 'sargodha', 'daejeon', 'st-gallen', 'rawalpindi', 'san-pedro', 'nampo', 'dakar', 'peshawar', 'xiangtan', 'haifa', 'tangshan', 'bahawalpur', 'mykonos', 'kenosha', 'kabul', 'zibo', 'managua', 'leon', 'handan', 'king-edward-point', 'islamabad', 'santa-teresa', 'ashgabat', 'tamarindo', 'faisalabad', 'multan', 'benghazi', 'tegucigalpa', 'gujranwala', 'ko-tao', 'bellevue', 'vatican-city', 'basra', 'yantai', 'sialkot', 'cayenne', 'martinique', 'san-pedro-sula', 'kralendijk', 'port-moresby', 'copan', 'ajaccio', 'ahvaz', 'khartoum', 'kuwait-city', 'hamamatsu', 'damascus', 'djibouti', 'changsha', 'bangui', 'bay-islands', 'yangzhou', 'jeddah', 'mecca', 'monrovia', 'noumea', 'tabarana-do-norte', 'ndjamena', 'kyiv', 'moscow', 'lviv', 'minsk', 'odessa', 'ivano-frankivsk', 'saint-petersburg', 'ufa', 'kharkiv', 'krasnodar', 'krasnoyarsk', 'dnipro', 'krivoy-rog', 'izhevsk', 'chelyabinsk', 'saratov', 'omsk', 'yekaterinburg', 'kaliningrad', 'ulyanovsk', 'obninsk', 'rostov-on-don', 'samara', 'novosibirsk', 'tomsk', 'vladivostok', 'kazan', 'nizhny']

# %%
urlbase = 'https://nomadlist.com/weather/'

score_desc=dict()

for i in cities:
    driver.get(urlbase + i)
    time.sleep(1)
    score=['Ciudad','Month']
    meses=['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']
    jan=[]
    feb=[]
    mar=[]
    apr=[]
    may=[]
    jun=[]
    jul=[]
    aug=[]
    sep=[]
    oct=[]
    nov=[]
    dec=[]
    wrong=['gran-canaria','belgrade','madeira','ko-pha-ngan','canggu','krakow','penang','playa-del-carmen','florianopolis','ubud','rio-de-janeiro','lagos-algarve','tallinn','cancun','coimbra','fuerteventura','portimao','taghazout','tulum','puerto-escondido','azores','chisinau','havana','el-gouna', 'seville', 'cebu', 'ottawa', 'willemstad', 'guanajuato', 'shanghai','queretaro', 'minneapolis', 'yangon', 'ploiesti', 'gdansk', 'riga', 'jeju-island', 'seattle', 'batumi', 'victoria', 'edmonton', 'cologne', 'paris', 'brussels', 'krabi', 'mumbai','luang-prabang','luang-prabang','poznan','skopje','tirana','almaty','porto-alegre','suva','phu-quoc','praia','galapagos-islands','puerto-vallarta','siargao','senggigi','queenstown','asuncion','marrakesh','sliema','vadodara','paramaribo','palermo','seminyak','jamshedpur','reykjavik','faro','ko-lanta','goa','salta','munggu','hua-hin','cairns','santo-domingo','kingston','rosario','mallorca','chittagong','cusco','tangier','gothenburg','salvador','el-jadida','hagen','ushuaia','arequipa','apia','sumperk','fortaleza','ranchi','georgetown','surabaya','jena','recife','cartagena','boracay','javea','san-pedro-de-atacama','rzeszow','da-lat','semarang','brasilia','montego-bay','alanya','wichita','gori','curitiba','allahabad','montevideo','port-louis','cork','sa-pa','natal','fes','windhoek','belem','amed','madurai','cavtat','makassar','victorville','harare','palmdale','ko-chang','luanda','belo-horizonte','bocas-del-toro','mui-ne','benin-city','grand-forks','antananarivo','jonesboro','gili-air','udon-thani','brazzaville','torshavn','killeen','chania','temple','menorca','hermosillo','mar-del-plata','rhodes','baku','alexandria','galle','ibadan','kigali','bareilly','santa-cruz','casablanca','campo-grande','mataram','bhubaneswar','luxor','freetown','cabo-san-lucas','bari','lubumbashi','san-cristobal-de-las-casas','itapema','wanaka','sao-luis','kano','gwalior','abuja','arugam-bay','thrissur','nukualofa','novocherkassk','la-paz','kannur','lanzarote','college-station','galway','cirebon','intag-valley','enid','nagasaki','khulna','goiania','srinagar','kandy','agadir','montanita','lusaka','aalborg','bryan','malappuram','mombasa','banjul','kozhikode','ko-lipe','raipur','hagatna','lynchburg','port-harcourt','el-alto','joplin','kollam','isla-mujeres','conakry','dahab','puning','sochi','rabat','bandung','joao-pessoa','barrie','mbuji-mayi','bucaramanga','matara','pasto','port-of-spain','campos-dos-goytacazes','oran','cozumel','guayaquil','sihanoukville','surat','jundiai','rovaniemi','oranjestad','dili','maseru','provo','klaipeda','uberlandia','ouagadougou','mendoza','uluwatu','padova','lome','kumasi','mandalay','chachapoyas','huambo','gaborone','kananga','mancora','janesville','wichita-falls','barranquilla','manaus','abidjan','naypyidaw','jarabacoa','rajkot','exeter','flagstaff','homs','volgograd','sanur','casa-grande','livingstone','essaouira','aarhus','juba','mcleod-ganj','tebessa','onitsha','douala','pyongyang','pueblo','bergen','dededo','kearney','jimbaran','kirkuk','nuuk','wonsan','tripoli','santa-marta','aligarh','lilongwe','aleppo','caracas','niamey','erlangen','minca','male','stanley','sayulita','maracay','kisangani','yamoussoukro','yaounde','jamestown','dar-es-salaam','malang','panajachel','denpasar','nouakchott','rethymno','port-au-prince','weston','centennial','kauai','venice','caye-caulker','maracaibo','bodrum','tanchon','maputo','sulaymaniyah','kaduna','duhok','santorini','bridgetown','avarua','lake-havasu-city','punta-cana','hama','san-ignacio','yogyakarta','surakarta','vang-vieng','punta-del-este','funafuti','anapolis','asmara','laayoune','honiara','kaechon','port-said','byron-bay','cagliari','abilene','st-johns','sanaa','key-west','kinshasa','belize-city','ithaca','mosul','san-juan-del-sur','accra','saint-helier','salento','kuta','darwin','medina','nassau','indio','quetta','libreville','road-town','port-vila','lagos','george-town','puerto-viejo','mogadishu','amundsen-scott','mcmurdo-station','chongjin','arendal','erbil','hamhung','philipsburg','muscat','san-angelo','zaria','charlotte-amalie','liberia','sariwon','constantine','ko-samui','cabarete','sargodha','san-pedro','nampo','bahawalpur','mykonos','managua','leon','king-edward-point','santa-teresa','tamarindo','faisalabad','multan','benghazi','tegucigalpa','gujranwala','ko-tao','sialkot','martinique','san-pedro-sula','kralendijk','port-moresby','copan','khartoum','damascus','djibouti','bangui','bay-islands','mecca','monrovia','tabarana-do-norte','ndjamena','kyiv','minsk','saint-petersburg','ufa','kharkiv','krasnodar','izhevsk','chelyabinsk','saratov','omsk','yekaterinburg','kaliningrad','ulyanovsk','obninsk','rostov-on-don','samara','novosibirsk','tomsk','vladivostok','kazan','nizhny']
#   if (i=='gran-canaria') or (i=='belgrade'):
    if i in wrong:

        jan.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(2) > span').text)
        feb.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(3) > span').text)
        mar.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(4) > span').text)
        apr.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(5) > span').text)
        may.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(6) > span').text)
        jun.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(7) > span').text)
        jul.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(8) > span').text)
        aug.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(9) > span').text)
        sep.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(10) > span').text)
        oct.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(11) > span').text)
        nov.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(12) > span').text)
        dec.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(8) > td:nth-child(13) > span').text)  
    
    else:
        
        jan.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(2) > span').text)
        feb.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(3) > span').text)
        mar.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(4) > span').text)
        apr.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(5) > span').text)
        may.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(6) > span').text)
        jun.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(7) > span').text)
        jul.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(8) > span').text)
        aug.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(9) > span').text)
        sep.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(10) > span').text)
        oct.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(11) > span').text)
        nov.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(12) > span').text)
        dec.append(driver.find_element_by_css_selector(f'body > div.modal.item.show.loaded > div:nth-child(7) > div.expandBelow > div.tab-scroller-container > div > div.tab.tab-weather.show > div > table > tbody > tr:nth-child(9) > td:nth-child(13) > span').text)  

    score_desc[f'{i}'] = dict(zip(meses,[jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec]))

# %%
score_desc
# Out:
# {'luang-prabang': {'jan': ['400 people'],
#   'feb': ['467 people'],
#   'mar': ['300 people'],
#   'apr': ['200 people'],
#   'may': ['300 people'],
#   'jun': ['333 people'],
#   'jul': ['200 people'],
#   'aug': ['350 people'],
#   'sep': ['200 people'],
#   'oct': ['320 people'],
#   'nov': ['375 people'],
#   'dec': ['400 people']},
#  'salt-lake-city': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n10 UVI'],
#   'jul': ['avoid sun\n10 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'varna': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'siem-reap': {'jan': ['avoid sun\n9 UVI'],
#   'feb': ['avoid sun\n10 UVI'],
#   'mar': ['avoid sun\n11 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['avoid sun\n7 UVI']},
#  'sarajevo': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'poznan': {'jan': ['257 people'],
#   'feb': ['250 people'],
#   'mar': ['333 people'],
#   'apr': ['360 people'],
#   'may': ['356 people'],
#   'jun': ['311 people'],
#   'jul': ['444 people'],
#   'aug': ['500 people'],
#   'sep': ['425 people'],
#   'oct': ['267 people'],
#   'nov': ['275 people'],
#   'dec': ['400 people']},
#  'skopje': {'jan': ['250 people'],
#   'feb': ['200 people'],
#   'mar': ['500 people'],
#   'apr': ['533 people'],
#   'may': ['440 people'],
#   'jun': ['367 people'],
#   'jul': ['314 people'],
#   'aug': ['400 people'],
#   'sep': ['400 people'],
#   'oct': ['367 people'],
#   'nov': ['320 people'],
#   'dec': ['300 people']},
#  'tirana': {'jan': ['320 people'],
#   'feb': ['320 people'],
#   'mar': ['400 people'],
#   'apr': ['467 people'],
#   'may': ['486 people'],
#   'jun': ['760 people'],
#   'jul': ['475 people'],
#   'aug': ['571 people'],
#   'sep': ['600 people'],
#   'oct': ['667 people'],
#   'nov': ['360 people'],
#   'dec': ['314 people']},
#  'perth': {'jan': ['avoid sun\n12 UVI'],
#   'feb': ['avoid sun\n11 UVI'],
#   'mar': ['avoid sun\n8 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['seek shade\n3 UVI'],
#   'jul': ['seek shade\n3 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['avoid sun\n8 UVI'],
#   'dec': ['avoid sun\n11 UVI']},
#  'aveiro': {'jan': ['safe\n2 UVI'],
#   'feb': ['safe\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'bratislava': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'christchurch': {'jan': ['avoid sun\n8 UVI'],
#   'feb': ['avoid sun\n7 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['safe\n2 UVI'],
#   'jun': ['safe\n1 UVI'],
#   'jul': ['safe\n1 UVI'],
#   'aug': ['safe\n2 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['avoid sun\n6 UVI']},
#  'hoi-an': {'jan': ['avoid sun\n6 UVI'],
#   'feb': ['avoid sun\n8 UVI'],
#   'mar': ['avoid sun\n9 UVI'],
#   'apr': ['avoid sun\n10 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['seek shade\n5 UVI'],
#   'dec': ['seek shade\n5 UVI']},
#  'almaty': {'jan': ['200 people'],
#   'feb': ['400 people'],
#   'mar': ['333 people'],
#   'apr': ['267 people'],
#   'may': ['333 people'],
#   'jun': ['300 people'],
#   'jul': ['300 people'],
#   'aug': ['367 people'],
#   'sep': ['240 people'],
#   'oct': ['300 people'],
#   'nov': ['250 people'],
#   'dec': ['200 people']},
#  'porto-alegre': {'jan': ['286 people'],
#   'feb': ['333 people'],
#   'mar': ['267 people'],
#   'apr': ['333 people'],
#   'may': ['300 people'],
#   'jun': ['200 people'],
#   'jul': ['267 people'],
#   'aug': ['300 people'],
#   'sep': ['360 people'],
#   'oct': ['280 people'],
#   'nov': ['240 people'],
#   'dec': ['360 people']},
#  'leipzig': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'suva': {'jan': ['0 people'],
#   'feb': ['200 people'],
#   'mar': ['0 people'],
#   'apr': ['200 people'],
#   'may': ['200 people'],
#   'jun': ['200 people'],
#   'jul': ['200 people'],
#   'aug': ['0 people'],
#   'sep': ['0 people'],
#   'oct': ['200 people'],
#   'nov': ['200 people'],
#   'dec': ['200 people']},
#  'phu-quoc': {'jan': ['280 people'],
#   'feb': ['200 people'],
#   'mar': ['267 people'],
#   'apr': ['400 people'],
#   'may': ['240 people'],
#   'jun': ['0 people'],
#   'jul': ['0 people'],
#   'aug': ['200 people'],
#   'sep': ['200 people'],
#   'oct': ['200 people'],
#   'nov': ['200 people'],
#   'dec': ['650 people']},
#  'guangzhou': {'jan': ['avoid sun\n6 UVI'],
#   'feb': ['avoid sun\n7 UVI'],
#   'mar': ['avoid sun\n6 UVI'],
#   'apr': ['avoid sun\n6 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['seek shade\n5 UVI'],
#   'dec': ['seek shade\n5 UVI']},
#  'praia': {'jan': ['200 people'],
#   'feb': ['200 people'],
#   'mar': ['0 people'],
#   'apr': ['0 people'],
#   'may': ['0 people'],
#   'jun': ['0 people'],
#   'jul': ['200 people'],
#   'aug': ['200 people'],
#   'sep': ['0 people'],
#   'oct': ['400 people'],
#   'nov': ['0 people'],
#   'dec': ['0 people']},
#  'katowice': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'tokyo': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['seek shade\n6 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'san-diego': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n5 UVI'],
#   'mar': ['avoid sun\n6 UVI'],
#   'apr': ['avoid sun\n8 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n4 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'phnom-penh': {'jan': ['avoid sun\n8 UVI'],
#   'feb': ['avoid sun\n10 UVI'],
#   'mar': ['avoid sun\n10 UVI'],
#   'apr': ['avoid sun\n8 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['avoid sun\n7 UVI']},
#  'galapagos-islands': {'jan': ['200 people'],
#   'feb': ['350 people'],
#   'mar': ['450 people'],
#   'apr': ['200 people'],
#   'may': ['400 people'],
#   'jun': ['200 people'],
#   'jul': ['200 people'],
#   'aug': ['200 people'],
#   'sep': ['200 people'],
#   'oct': ['200 people'],
#   'nov': ['233 people'],
#   'dec': ['200 people']},
#  'nairobi': {'jan': ['avoid sun\n9 UVI'],
#   'feb': ['avoid sun\n8 UVI'],
#   'mar': ['avoid sun\n10 UVI'],
#   'apr': ['avoid sun\n8 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n9 UVI'],
#   'nov': ['avoid sun\n8 UVI'],
#   'dec': ['avoid sun\n8 UVI']},
#  'palawan': {'jan': ['avoid sun\n6 UVI'],
#   'feb': ['avoid sun\n7 UVI'],
#   'mar': ['avoid sun\n8 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['avoid sun\n6 UVI']},
#  'orlando': {'jan': ['seek shade\n4 UVI'],
#   'feb': ['avoid sun\n6 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['avoid sun\n9 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['seek shade\n4 UVI'],
#   'dec': ['seek shade\n4 UVI']},
#  'puerto-vallarta': {'jan': ['943 people'],
#   'feb': ['967 people'],
#   'mar': ['556 people'],
#   'apr': ['756 people'],
#   'may': ['356 people'],
#   'jun': ['500 people'],
#   'jul': ['425 people'],
#   'aug': ['429 people'],
#   'sep': ['400 people'],
#   'oct': ['425 people'],
#   'nov': ['1,100 people'],
#   'dec': ['975 people']},
#  'nis': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'lodz': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['seek shade\n6 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'siargao': {'jan': ['200 people'],
#   'feb': ['333 people'],
#   'mar': ['200 people'],
#   'apr': ['200 people'],
#   'may': ['0 people'],
#   'jun': ['0 people'],
#   'jul': ['0 people'],
#   'aug': ['200 people'],
#   'sep': ['200 people'],
#   'oct': ['200 people'],
#   'nov': ['400 people'],
#   'dec': ['0 people']},
#  'frankfurt': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'dusseldorf': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'lille': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'new-orleans': {'jan': ['seek shade\n4 UVI'],
#   'feb': ['seek shade\n5 UVI'],
#   'mar': ['avoid sun\n6 UVI'],
#   'apr': ['avoid sun\n9 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['seek shade\n5 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'aberdeen': {'jan': ['safe\n0 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['seek shade\n4 UVI'],
#   'jul': ['seek shade\n4 UVI'],
#   'aug': ['seek shade\n3 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n1 UVI'],
#   'nov': ['safe\n0 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'winnipeg': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'brampton': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'liverpool': {'jan': ['safe\n0 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['seek shade\n4 UVI'],
#   'jul': ['seek shade\n4 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'senggigi': {'jan': ['0 people'],
#   'feb': ['200 people'],
#   'mar': ['200 people'],
#   'apr': ['200 people'],
#   'may': ['200 people'],
#   'jun': ['200 people'],
#   'jul': ['200 people'],
#   'aug': ['200 people'],
#   'sep': ['0 people'],
#   'oct': ['200 people'],
#   'nov': ['200 people'],
#   'dec': ['0 people']},
#  'lublin': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'tartu': {'jan': ['safe\n0 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n1 UVI'],
#   'apr': ['safe\n2 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n3 UVI'],
#   'sep': ['safe\n3 UVI'],
#   'oct': ['safe\n1 UVI'],
#   'nov': ['safe\n0 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'queenstown': {'jan': ['375 people'],
#   'feb': ['433 people'],
#   'mar': ['400 people'],
#   'apr': ['229 people'],
#   'may': ['200 people'],
#   'jun': ['300 people'],
#   'jul': ['367 people'],
#   'aug': ['229 people'],
#   'sep': ['200 people'],
#   'oct': ['360 people'],
#   'nov': ['480 people'],
#   'dec': ['533 people']},
#  'asuncion': {'jan': ['286 people'],
#   'feb': ['280 people'],
#   'mar': ['200 people'],
#   'apr': ['367 people'],
#   'may': ['240 people'],
#   'jun': ['200 people'],
#   'jul': ['267 people'],
#   'aug': ['250 people'],
#   'sep': ['280 people'],
#   'oct': ['200 people'],
#   'nov': ['300 people'],
#   'dec': ['500 people']},
#  'hyderabad': {'jan': ['avoid sun\n8 UVI'],
#   'feb': ['avoid sun\n9 UVI'],
#   'mar': ['avoid sun\n12 UVI'],
#   'apr': ['avoid sun\n11 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['avoid sun\n7 UVI']},
#  'port-elizabeth': {'jan': ['avoid sun\n10 UVI'],
#   'feb': ['avoid sun\n9 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['seek shade\n3 UVI'],
#   'jul': ['seek shade\n3 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['avoid sun\n7 UVI'],
#   'dec': ['avoid sun\n8 UVI']},
#  'paphos': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['avoid sun\n6 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n10 UVI'],
#   'jul': ['avoid sun\n10 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'lake-balaton': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'newcastle-upon-tyne': {'jan': ['safe\n0 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['seek shade\n4 UVI'],
#   'jul': ['seek shade\n4 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'osijek': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'pretoria': {'jan': ['avoid sun\n9 UVI'],
#   'feb': ['avoid sun\n10 UVI'],
#   'mar': ['avoid sun\n10 UVI'],
#   'apr': ['avoid sun\n8 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n9 UVI'],
#   'oct': ['avoid sun\n10 UVI'],
#   'nov': ['avoid sun\n11 UVI'],
#   'dec': ['avoid sun\n8 UVI']},
#  'calgary': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'cuenca': {'jan': ['avoid sun\n8 UVI'],
#   'feb': ['avoid sun\n9 UVI'],
#   'mar': ['avoid sun\n8 UVI'],
#   'apr': ['avoid sun\n8 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n9 UVI'],
#   'nov': ['avoid sun\n9 UVI'],
#   'dec': ['avoid sun\n8 UVI']},
#  'marrakesh': {'jan': ['523 people'],
#   'feb': ['533 people'],
#   'mar': ['520 people'],
#   'apr': ['564 people'],
#   'may': ['771 people'],
#   'jun': ['650 people'],
#   'jul': ['323 people'],
#   'aug': ['400 people'],
#   'sep': ['543 people'],
#   'oct': ['629 people'],
#   'nov': ['911 people'],
#   'dec': ['644 people']},
#  'monterrey': {'jan': ['seek shade\n5 UVI'],
#   'feb': ['avoid sun\n7 UVI'],
#   'mar': ['avoid sun\n9 UVI'],
#   'apr': ['avoid sun\n10 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n10 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n10 UVI'],
#   'sep': ['avoid sun\n9 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['seek shade\n6 UVI'],
#   'dec': ['seek shade\n5 UVI']},
#  'sliema': {'jan': ['782 people'],
#   'feb': ['564 people'],
#   'mar': ['520 people'],
#   'apr': ['844 people'],
#   'may': ['500 people'],
#   'jun': ['483 people'],
#   'jul': ['567 people'],
#   'aug': ['431 people'],
#   'sep': ['600 people'],
#   'oct': ['836 people'],
#   'nov': ['889 people'],
#   'dec': ['550 people']},
#  'saskatoon': {'jan': ['safe\n0 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'osaka': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'regina': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'kansas-city': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['avoid sun\n6 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'vadodara': {'jan': ['0 people'],
#   'feb': ['0 people'],
#   'mar': ['0 people'],
#   'apr': ['0 people'],
#   'may': ['0 people'],
#   'jun': ['0 people'],
#   'jul': ['0 people'],
#   'aug': ['0 people'],
#   'sep': ['0 people'],
#   'oct': ['0 people'],
#   'nov': ['0 people'],
#   'dec': ['200 people']},
#  'fayetteville': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'paramaribo': {'jan': ['200 people'],
#   'feb': ['200 people'],
#   'mar': ['0 people'],
#   'apr': ['0 people'],
#   'may': ['0 people'],
#   'jun': ['200 people'],
#   'jul': ['200 people'],
#   'aug': ['0 people'],
#   'sep': ['200 people'],
#   'oct': ['200 people'],
#   'nov': ['0 people'],
#   'dec': ['0 people']},
#  'haikou': {'jan': ['avoid sun\n7 UVI'],
#   'feb': ['avoid sun\n8 UVI'],
#   'mar': ['avoid sun\n8 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['seek shade\n5 UVI']},
#  'san-antonio': {'jan': ['seek shade\n4 UVI'],
#   'feb': ['seek shade\n5 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['avoid sun\n8 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n9 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['seek shade\n4 UVI'],
#   'dec': ['seek shade\n4 UVI']},
#  'palermo': {'jan': ['400 people'],
#   'feb': ['267 people'],
#   'mar': ['433 people'],
#   'apr': ['600 people'],
#   'may': ['680 people'],
#   'jun': ['250 people'],
#   'jul': ['380 people'],
#   'aug': ['360 people'],
#   'sep': ['400 people'],
#   'oct': ['333 people'],
#   'nov': ['300 people'],
#   'dec': ['240 people']},
#  'amman': {'jan': ['seek shade\n4 UVI'],
#   'feb': ['seek shade\n5 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['avoid sun\n9 UVI'],
#   'may': ['avoid sun\n11 UVI'],
#   'jun': ['avoid sun\n12 UVI'],
#   'jul': ['avoid sun\n12 UVI'],
#   'aug': ['avoid sun\n11 UVI'],
#   'sep': ['avoid sun\n9 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['seek shade\n4 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'general-santos': {'jan': ['avoid sun\n7 UVI'],
#   'feb': ['avoid sun\n7 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['avoid sun\n7 UVI'],
#   'dec': ['avoid sun\n6 UVI']},
#  'adelaide': {'jan': ['avoid sun\n10 UVI'],
#   'feb': ['avoid sun\n9 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['safe\n2 UVI'],
#   'jul': ['safe\n2 UVI'],
#   'aug': ['seek shade\n3 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['avoid sun\n11 UVI']},
#  'antigua': {'jan': ['avoid sun\n8 UVI'],
#   'feb': ['avoid sun\n11 UVI'],
#   'mar': ['avoid sun\n11 UVI'],
#   'apr': ['avoid sun\n9 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n8 UVI'],
#   'nov': ['avoid sun\n8 UVI'],
#   'dec': ['avoid sun\n8 UVI']},
#  'seminyak': {'jan': ['720 people'],
#   'feb': ['450 people'],
#   'mar': ['567 people'],
#   'apr': ['400 people'],
#   'may': ['600 people'],
#   'jun': ['500 people'],
#   'jul': ['500 people'],
#   'aug': ['425 people'],
#   'sep': ['350 people'],
#   'oct': ['371 people'],
#   'nov': ['567 people'],
#   'dec': ['629 people']},
#  'toulouse': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'kota-kinabalu': {'jan': ['avoid sun\n7 UVI'],
#   'feb': ['avoid sun\n8 UVI'],
#   'mar': ['avoid sun\n9 UVI'],
#   'apr': ['avoid sun\n8 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['avoid sun\n7 UVI'],
#   'dec': ['avoid sun\n6 UVI']},
#  'busan': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'mcallen': {'jan': ['seek shade\n5 UVI'],
#   'feb': ['seek shade\n6 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['avoid sun\n9 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n10 UVI'],
#   'sep': ['avoid sun\n9 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['seek shade\n5 UVI'],
#   'dec': ['seek shade\n5 UVI']},
#  'jamshedpur': {'jan': ['0 people'],
#   'feb': ['0 people'],
#   'mar': ['0 people'],
#   'apr': ['0 people'],
#   'may': ['0 people'],
#   'jun': ['0 people'],
#   'jul': ['0 people'],
#   'aug': ['0 people'],
#   'sep': ['0 people'],
#   'oct': ['0 people'],
#   'nov': ['200 people'],
#   'dec': ['0 people']},
#  'rijeka': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'oaxaca': {'jan': ['avoid sun\n8 UVI'],
#   'feb': ['avoid sun\n11 UVI'],
#   'mar': ['avoid sun\n13 UVI'],
#   'apr': ['avoid sun\n12 UVI'],
#   'may': ['avoid sun\n11 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n8 UVI'],
#   'nov': ['avoid sun\n8 UVI'],
#   'dec': ['avoid sun\n8 UVI']},
#  'kuching': {'jan': ['avoid sun\n6 UVI'],
#   'feb': ['avoid sun\n7 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['avoid sun\n6 UVI']},
#  'rotterdam': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'winston': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'ogden': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['avoid sun\n10 UVI'],
#   'jul': ['avoid sun\n10 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'dhanbad': {'jan': ['avoid sun\n6 UVI'],
#   'feb': ['avoid sun\n8 UVI'],
#   'mar': ['avoid sun\n10 UVI'],
#   'apr': ['avoid sun\n11 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['seek shade\n5 UVI']},
#  'columbus': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'pattaya': {'jan': ['avoid sun\n9 UVI'],
#   'feb': ['avoid sun\n10 UVI'],
#   'mar': ['avoid sun\n10 UVI'],
#   'apr': ['avoid sun\n6 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['avoid sun\n7 UVI'],
#   'dec': ['avoid sun\n7 UVI']},
#  'reykjavik': {'jan': ['560 people'],
#   'feb': ['514 people'],
#   'mar': ['740 people'],
#   'apr': ['520 people'],
#   'may': ['756 people'],
#   'jun': ['873 people'],
#   'jul': ['729 people'],
#   'aug': ['629 people'],
#   'sep': ['564 people'],
#   'oct': ['527 people'],
#   'nov': ['800 people'],
#   'dec': ['650 people']},
#  'faro': {'jan': ['200 people'],
#   'feb': ['250 people'],
#   'mar': ['314 people'],
#   'apr': ['200 people'],
#   'may': ['240 people'],
#   'jun': ['267 people'],
#   'jul': ['320 people'],
#   'aug': ['250 people'],
#   'sep': ['480 people'],
#   'oct': ['400 people'],
#   'nov': ['300 people'],
#   'dec': ['333 people']},
#  'sioux-falls': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'brisbane': {'jan': ['avoid sun\n8 UVI'],
#   'feb': ['avoid sun\n8 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['avoid sun\n6 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['seek shade\n4 UVI'],
#   'jul': ['seek shade\n4 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['avoid sun\n8 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['avoid sun\n7 UVI']},
#  'beirut': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['avoid sun\n8 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n10 UVI'],
#   'jul': ['avoid sun\n10 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'nantes': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'malmo': {'jan': ['safe\n0 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n1 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'stuttgart': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'baguio': {'jan': ['avoid sun\n7 UVI'],
#   'feb': ['avoid sun\n8 UVI'],
#   'mar': ['avoid sun\n10 UVI'],
#   'apr': ['avoid sun\n9 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['avoid sun\n6 UVI']},
#  'ko-lanta': {'jan': ['960 people'],
#   'feb': ['1,467 people'],
#   'mar': ['1,400 people'],
#   'apr': ['660 people'],
#   'may': ['400 people'],
#   'jun': ['429 people'],
#   'jul': ['280 people'],
#   'aug': ['320 people'],
#   'sep': ['880 people'],
#   'oct': ['800 people'],
#   'nov': ['975 people'],
#   'dec': ['857 people']},
#  'craiova': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'goa': {'jan': ['311 people'],
#   'feb': ['467 people'],
#   'mar': ['367 people'],
#   'apr': ['200 people'],
#   'may': ['400 people'],
#   'jun': ['280 people'],
#   'jul': ['350 people'],
#   'aug': ['200 people'],
#   'sep': ['300 people'],
#   'oct': ['233 people'],
#   'nov': ['582 people'],
#   'dec': ['567 people']},
#  'salta': {'jan': ['200 people'],
#   'feb': ['200 people'],
#   'mar': ['0 people'],
#   'apr': ['400 people'],
#   'may': ['400 people'],
#   'jun': ['200 people'],
#   'jul': ['200 people'],
#   'aug': ['200 people'],
#   'sep': ['200 people'],
#   'oct': ['250 people'],
#   'nov': ['467 people'],
#   'dec': ['200 people']},
#  'manchester': {'jan': ['safe\n0 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['seek shade\n4 UVI'],
#   'jul': ['seek shade\n4 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'munggu': {'jan': ['200 people'],
#   'feb': ['0 people'],
#   'mar': ['0 people'],
#   'apr': ['0 people'],
#   'may': ['0 people'],
#   'jun': ['0 people'],
#   'jul': ['0 people'],
#   'aug': ['0 people'],
#   'sep': ['0 people'],
#   'oct': ['200 people'],
#   'nov': ['0 people'],
#   'dec': ['0 people']},
#  'kathmandu': {'jan': ['seek shade\n5 UVI'],
#   'feb': ['avoid sun\n6 UVI'],
#   'mar': ['avoid sun\n9 UVI'],
#   'apr': ['avoid sun\n10 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['seek shade\n5 UVI'],
#   'dec': ['seek shade\n5 UVI']},
#  'hua-hin': {'jan': ['400 people'],
#   'feb': ['200 people'],
#   'mar': ['333 people'],
#   'apr': ['280 people'],
#   'may': ['200 people'],
#   'jun': ['250 people'],
#   'jul': ['280 people'],
#   'aug': ['400 people'],
#   'sep': ['320 people'],
#   'oct': ['333 people'],
#   'nov': ['440 people'],
#   'dec': ['360 people']},
#  'zadar': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'banja-luka': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'surrey': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'leicester': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['seek shade\n4 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'cairns': {'jan': ['200 people'],
#   'feb': ['240 people'],
#   'mar': ['333 people'],
#   'apr': ['350 people'],
#   'may': ['360 people'],
#   'jun': ['257 people'],
#   'jul': ['229 people'],
#   'aug': ['240 people'],
#   'sep': ['200 people'],
#   'oct': ['325 people'],
#   'nov': ['233 people'],
#   'dec': ['200 people']},
#  'la-union': {'jan': ['avoid sun\n7 UVI'],
#   'feb': ['avoid sun\n9 UVI'],
#   'mar': ['avoid sun\n10 UVI'],
#   'apr': ['avoid sun\n10 UVI'],
#   'may': ['avoid sun\n10 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['avoid sun\n7 UVI'],
#   'dec': ['avoid sun\n6 UVI']},
#  'kingsport': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['avoid sun\n6 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'montpellier': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'kochi': {'jan': ['avoid sun\n9 UVI'],
#   'feb': ['avoid sun\n10 UVI'],
#   'mar': ['avoid sun\n10 UVI'],
#   'apr': ['avoid sun\n9 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['avoid sun\n8 UVI']},
#  'hilo': {'jan': ['seek shade\n5 UVI'],
#   'feb': ['avoid sun\n7 UVI'],
#   'mar': ['avoid sun\n6 UVI'],
#   'apr': ['avoid sun\n8 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['seek shade\n5 UVI']},
#  'la-plata': {'jan': ['avoid sun\n12 UVI'],
#   'feb': ['avoid sun\n8 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['safe\n2 UVI'],
#   'jul': ['seek shade\n3 UVI'],
#   'aug': ['seek shade\n3 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['avoid sun\n8 UVI'],
#   'nov': ['avoid sun\n9 UVI'],
#   'dec': ['avoid sun\n10 UVI']},
#  'birmingham': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['seek shade\n4 UVI'],
#   'jul': ['seek shade\n4 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'limassol': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n10 UVI'],
#   'jul': ['avoid sun\n11 UVI'],
#   'aug': ['avoid sun\n10 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'gainesville': {'jan': ['seek shade\n4 UVI'],
#   'feb': ['seek shade\n5 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['avoid sun\n9 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['seek shade\n4 UVI'],
#   'dec': ['seek shade\n4 UVI']},
#  'guadalajara': {'jan': ['avoid sun\n7 UVI'],
#   'feb': ['avoid sun\n9 UVI'],
#   'mar': ['avoid sun\n12 UVI'],
#   'apr': ['avoid sun\n13 UVI'],
#   'may': ['avoid sun\n12 UVI'],
#   'jun': ['avoid sun\n9 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n8 UVI'],
#   'nov': ['avoid sun\n8 UVI'],
#   'dec': ['avoid sun\n7 UVI']},
#  'nuremberg': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'eau-claire': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'abbotsford': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'indianapolis': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'fargo': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'hull': {'jan': ['safe\n0 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['safe\n2 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['seek shade\n4 UVI'],
#   'jul': ['seek shade\n4 UVI'],
#   'aug': ['seek shade\n4 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['safe\n2 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'santo-domingo': {'jan': ['240 people'],
#   'feb': ['450 people'],
#   'mar': ['350 people'],
#   'apr': ['200 people'],
#   'may': ['250 people'],
#   'jun': ['200 people'],
#   'jul': ['286 people'],
#   'aug': ['200 people'],
#   'sep': ['300 people'],
#   'oct': ['350 people'],
#   'nov': ['300 people'],
#   'dec': ['240 people']},
#  'dunedin': {'jan': ['avoid sun\n6 UVI'],
#   'feb': ['avoid sun\n6 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['safe\n1 UVI'],
#   'jun': ['safe\n1 UVI'],
#   'jul': ['safe\n1 UVI'],
#   'aug': ['safe\n2 UVI'],
#   'sep': ['seek shade\n3 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['seek shade\n5 UVI'],
#   'dec': ['avoid sun\n6 UVI']},
#  'mysore': {'jan': ['avoid sun\n8 UVI'],
#   'feb': ['avoid sun\n11 UVI'],
#   'mar': ['avoid sun\n12 UVI'],
#   'apr': ['avoid sun\n9 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['avoid sun\n7 UVI']},
#  'laredo': {'jan': ['seek shade\n4 UVI'],
#   'feb': ['avoid sun\n6 UVI'],
#   'mar': ['avoid sun\n8 UVI'],
#   'apr': ['avoid sun\n9 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n10 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n10 UVI'],
#   'sep': ['avoid sun\n9 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['seek shade\n5 UVI'],
#   'dec': ['seek shade\n4 UVI']},
#  'beaumont': {'jan': ['seek shade\n4 UVI'],
#   'feb': ['seek shade\n5 UVI'],
#   'mar': ['avoid sun\n6 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['seek shade\n4 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'naha': {'jan': ['seek shade\n4 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['seek shade\n4 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['safe\n3 UVI'],
#   'dec': ['seek shade\n4 UVI']},
#  'pittsburgh': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n6 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'cincinnati': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'fukuoka': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['avoid sun\n6 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
# ...
#   'feb': ['0 people'],
#   'mar': ['0 people'],
#   'apr': ['0 people'],
#   'may': ['0 people'],
#   'jun': ['0 people'],
#   'jul': ['0 people'],
#   'aug': ['0 people'],
#   'sep': ['0 people'],
#   'oct': ['0 people'],
#   'nov': ['0 people'],
#   'dec': ['0 people']},
#  'palo-alto': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['avoid sun\n10 UVI'],
#   'jul': ['avoid sun\n10 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'port-said': {'jan': ['0 people'],
#   'feb': ['0 people'],
#   'mar': ['0 people'],
#   'apr': ['0 people'],
#   'may': ['200 people'],
#   'jun': ['0 people'],
#   'jul': ['0 people'],
#   'aug': ['0 people'],
#   'sep': ['0 people'],
#   'oct': ['0 people'],
#   'nov': ['0 people'],
#   'dec': ['0 people']},
#  'wuhan': {'jan': ['seek shade\n4 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n4 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'bamako': {'jan': ['avoid sun\n9 UVI'],
#   'feb': ['avoid sun\n11 UVI'],
#   'mar': ['avoid sun\n11 UVI'],
#   'apr': ['avoid sun\n10 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['avoid sun\n8 UVI'],
#   'dec': ['avoid sun\n8 UVI']},
#  'kobe': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'san-clemente': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n5 UVI'],
#   'mar': ['avoid sun\n6 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['avoid sun\n9 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['seek shade\n4 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'siena': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'byron-bay': {'jan': ['200 people'],
#   'feb': ['367 people'],
#   'mar': ['400 people'],
#   'apr': ['0 people'],
#   'may': ['233 people'],
#   'jun': ['200 people'],
#   'jul': ['200 people'],
#   'aug': ['200 people'],
#   'sep': ['200 people'],
#   'oct': ['400 people'],
#   'nov': ['267 people'],
#   'dec': ['314 people']},
#  'linyi': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'ludhiana': {'jan': ['seek shade\n4 UVI'],
#   'feb': ['seek shade\n5 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['avoid sun\n9 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n11 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n7 UVI'],
#   'nov': ['seek shade\n5 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'nice': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'newport-beach': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n5 UVI'],
#   'mar': ['avoid sun\n6 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n9 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n4 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'manhattan': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n6 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'anchorage': {'jan': ['safe\n0 UVI'],
#   'feb': ['safe\n0 UVI'],
#   'mar': ['safe\n1 UVI'],
#   'apr': ['safe\n2 UVI'],
#   'may': ['seek shade\n3 UVI'],
#   'jun': ['seek shade\n4 UVI'],
#   'jul': ['seek shade\n4 UVI'],
#   'aug': ['seek shade\n3 UVI'],
#   'sep': ['safe\n2 UVI'],
#   'oct': ['safe\n1 UVI'],
#   'nov': ['safe\n0 UVI'],
#   'dec': ['safe\n0 UVI']},
#  'west-palm-beach': {'jan': ['seek shade\n5 UVI'],
#   'feb': ['avoid sun\n6 UVI'],
#   'mar': ['avoid sun\n7 UVI'],
#   'apr': ['avoid sun\n9 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n8 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['seek shade\n5 UVI'],
#   'dec': ['seek shade\n4 UVI']},
#  'kota': {'jan': ['avoid sun\n6 UVI'],
#   'feb': ['avoid sun\n7 UVI'],
#   'mar': ['avoid sun\n9 UVI'],
#   'apr': ['avoid sun\n11 UVI'],
#   'may': ['avoid sun\n11 UVI'],
#   'jun': ['avoid sun\n10 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['avoid sun\n8 UVI'],
#   'nov': ['avoid sun\n6 UVI'],
#   'dec': ['seek shade\n5 UVI']},
#  'cagliari': {'jan': ['0 people'],
#   'feb': ['267 people'],
#   'mar': ['200 people'],
#   'apr': ['0 people'],
#   'may': ['0 people'],
#   'jun': ['200 people'],
#   'jul': ['333 people'],
#   'aug': ['0 people'],
#   'sep': ['400 people'],
#   'oct': ['267 people'],
#   'nov': ['200 people'],
#   'dec': ['200 people']},
#  'oxnard': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['safe\n0 UVI'],
#   'mar': ['avoid sun\n6 UVI'],
#   'apr': ['safe\n0 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['safe\n0 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['safe\n0 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['safe\n0 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'tianjin': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'abilene': {'jan': ['0 people'],
#   'feb': ['0 people'],
#   'mar': ['0 people'],
#   'apr': ['0 people'],
#   'may': ['0 people'],
#   'jun': ['0 people'],
#   'jul': ['0 people'],
#   'aug': ['200 people'],
#   'sep': ['0 people'],
#   'oct': ['0 people'],
#   'nov': ['0 people'],
#   'dec': ['200 people']},
#  'mountain-view': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['avoid sun\n10 UVI'],
#   'jul': ['avoid sun\n10 UVI'],
#   'aug': ['avoid sun\n9 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'anshan': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'dorobo': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['seek shade\n4 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n4 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'sinuiju': {'jan': ['safe\n2 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['seek shade\n5 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'princeton': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'st-johns': {'jan': ['200 people'],
#   'feb': ['200 people'],
#   'mar': ['200 people'],
#   'apr': ['200 people'],
#   'may': ['0 people'],
#   'jun': ['200 people'],
#   'jul': ['0 people'],
#   'aug': ['0 people'],
#   'sep': ['0 people'],
#   'oct': ['0 people'],
#   'nov': ['200 people'],
#   'dec': ['267 people']},
#  'sanaa': {'jan': ['200 people'],
#   'feb': ['0 people'],
#   'mar': ['0 people'],
#   'apr': ['200 people'],
#   'may': ['0 people'],
#   'jun': ['0 people'],
#   'jul': ['200 people'],
#   'aug': ['0 people'],
#   'sep': ['0 people'],
#   'oct': ['0 people'],
#   'nov': ['0 people'],
#   'dec': ['0 people']},
#  'amalfi': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'grand-island': {'jan': ['safe\n2 UVI'],
#   'feb': ['safe\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n6 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n9 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'key-west': {'jan': ['200 people'],
#   'feb': ['200 people'],
#   'mar': ['350 people'],
#   'apr': ['200 people'],
#   'may': ['200 people'],
#   'jun': ['200 people'],
#   'jul': ['200 people'],
#   'aug': ['200 people'],
#   'sep': ['200 people'],
#   'oct': ['267 people'],
#   'nov': ['267 people'],
#   'dec': ['267 people']},
#  'waukegan': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n4 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'weihai': {'jan': ['safe\n2 UVI'],
#   'feb': ['safe\n2 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['safe\n3 UVI'],
#   'may': ['avoid sun\n6 UVI'],
#   'jun': ['safe\n3 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['safe\n3 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'wilmington': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['avoid sun\n8 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'pensacola': {'jan': ['seek shade\n4 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['avoid sun\n6 UVI'],
#   'apr': ['avoid sun\n8 UVI'],
#   'may': ['avoid sun\n9 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['avoid sun\n6 UVI'],
#   'nov': ['seek shade\n4 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'yinchuan': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['avoid sun\n6 UVI'],
#   'may': ['avoid sun\n8 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'duluth': {'jan': ['safe\n1 UVI'],
#   'feb': ['safe\n1 UVI'],
#   'mar': ['seek shade\n3 UVI'],
#   'apr': ['seek shade\n3 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n7 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n3 UVI'],
#   'nov': ['safe\n1 UVI'],
#   'dec': ['safe\n1 UVI']},
#  'frederick': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'dongying': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n4 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n6 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['seek shade\n5 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'ube': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['safe\n0 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['safe\n0 UVI'],
#   'may': ['seek shade\n5 UVI'],
#   'jun': ['safe\n0 UVI'],
#   'jul': ['seek shade\n5 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['safe\n0 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['safe\n0 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'ibiza': {'jan': ['safe\n2 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n9 UVI'],
#   'aug': ['avoid sun\n7 UVI'],
#   'sep': ['seek shade\n5 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['safe\n2 UVI'],
#   'dec': ['safe\n2 UVI']},
#  'memphis': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n3 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['avoid sun\n7 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n8 UVI'],
#   'jul': ['avoid sun\n8 UVI'],
#   'aug': ['avoid sun\n8 UVI'],
#   'sep': ['avoid sun\n7 UVI'],
#   'oct': ['seek shade\n5 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': ['seek shade\n3 UVI']},
#  'xuzhou': {'jan': ['seek shade\n3 UVI'],
#   'feb': ['seek shade\n4 UVI'],
#   'mar': ['seek shade\n5 UVI'],
#   'apr': ['seek shade\n5 UVI'],
#   'may': ['avoid sun\n7 UVI'],
#   'jun': ['avoid sun\n7 UVI'],
#   'jul': ['avoid sun\n6 UVI'],
#   'aug': ['avoid sun\n6 UVI'],
#   'sep': ['avoid sun\n6 UVI'],
#   'oct': ['seek shade\n4 UVI'],
#   'nov': ['seek shade\n3 UVI'],
#   'dec': 