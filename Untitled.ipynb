# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./6_final_info.csv')

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df['Ciudad_Country']=df.City+', '+df.Country

# %%
df
# Out:
#               City  ⭐️ Total score 👍 Quality of life score 👶 Family score  \
# 0         Ericeira            4.57                    Good           Good
# 1           Lisbon            4.69                    Good           Good
# 2            Miami            4.64                    Good           Good
# 3     Gran Canaria            4.84                    Good           Good
# 4         Budapest            4.60                    Good           Good
# ...            ...             ...                     ...            ...
# 1336   Novosibirsk            0.18                    Okay            Bad
# 1337         Tomsk            0.03                    Okay           Okay
# 1338   Vladivostok           -0.12                    Okay            Bad
# 1339         Kazan           -0.15                    Okay            Bad
# 1340        Nizhny           -0.25                    Okay            Bad
#
#              💵 Cost  📡 Internet  😝 Fun                          👌 Safety  \
# ...

# %%
df.to_excel('./_final_info.xlsx')
