# %%
#pip install selenium

# %%
import pandas as pd
import numpy as np

# %%
from selenium import webdriver
import pandas as pd
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
import time

import warnings
warnings.filterwarnings('ignore')

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
driver = "./chromedriver.exe" #remember substitute this for your driver path
driver = webdriver.Chrome(ChromeDriverManager().install(),options = opciones)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\patri\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache

# %%
urlbase = 'https://nomadlist.com/'
driver.get(urlbase)

# %%
#base=driver.find_element_by_tag_name('ul')

# %%
#driver.find_elements_by_tag_name('li')[4].get_attribute('data-slug')

# %%
# scroll , codigo javascript
count=1
while count<55:
    try:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(2)
        count +=1
    except:
        break

# %%
cities=[]
for elemento in driver.find_elements_by_tag_name('li'):
    print(elemento.get_attribute('data-slug'))
    cities.append(elemento.get_attribute('data-slug'))
# Out:
# lisbon
# ericeira
# miami
# gran-canaria
# budapest
# porto
# austin
# tbilisi
# warsaw
# sofia
# chiang-mai
# bangkok
# {slug}
# istanbul
# cape-town
# canggu
# mexico-city
# singapore
# buenos-aires
# belgrade
# phuket
# madeira
# ko-pha-ngan
# valencia
# prague
# ubud
# seoul
# toronto
# melbourne
# sao-paulo
# da-nang
# timisoara
# berlin
# playa-del-carmen
# bengaluru
# kuala-lumpur
# stockholm
# split
# tenerife
# krakow
# wroclaw
# zagreb
# penang
# honolulu
# puerto-escondido
# bucharest
# atlanta
# auckland
# antalya
# new-york-city
# copenhagen
# sydney
# cluj
# athens
# medellin
# ljubljana
# yerevan
# vancouver
# madrid
# florianopolis
# munich
# taipei
# lima
# london
# brasov
# barcelona
# los-angeles
# gdansk
# cancun
# las-vegas
# manila
# lagos-algarve
# amsterdam
# tulum
# denver
# tallinn
# rio-de-janeiro
# wellington
# kotor
# vienna
# novi-sad
# ho-chi-minh-city
# hamburg
# boston
# jeju-island
# fuerteventura
# portimao
# vilnius
# san-francisco
# varna
# ...

# %%
print(cities)
# Out:
# ['', 'lisbon', 'ericeira', 'miami', 'gran-canaria', 'budapest', 'porto', 'austin', 'tbilisi', 'warsaw', 'sofia', 'chiang-mai', 'bangkok', '{slug}', 'istanbul', 'cape-town', 'canggu', 'mexico-city', 'singapore', 'buenos-aires', 'belgrade', 'phuket', 'madeira', 'ko-pha-ngan', 'valencia', 'prague', 'ubud', 'seoul', 'toronto', 'melbourne', 'sao-paulo', 'da-nang', 'timisoara', 'berlin', 'playa-del-carmen', 'bengaluru', 'kuala-lumpur', 'stockholm', 'split', 'tenerife', 'krakow', 'wroclaw', 'zagreb', 'penang', 'honolulu', 'puerto-escondido', 'bucharest', 'atlanta', 'auckland', 'antalya', 'new-york-city', 'copenhagen', 'sydney', 'cluj', 'athens', 'medellin', 'ljubljana', 'yerevan', 'vancouver', 'madrid', 'florianopolis', 'munich', 'taipei', 'lima', 'london', 'brasov', 'barcelona', 'los-angeles', 'gdansk', 'cancun', 'las-vegas', 'manila', 'lagos-algarve', 'amsterdam', 'tulum', 'denver', 'tallinn', 'rio-de-janeiro', 'wellington', 'kotor', 'vienna', 'novi-sad', 'ho-chi-minh-city', 'hamburg', 'b
# ...

# %%
len(cities)
# Out:
# 1345

# %%
cities.pop(0)
# Out:
# ''

# %%
cities.remove('{slug}')

# %%
# scroll , codigo javascript
driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
time.sleep(2)

# %%
# scroll , codigo javascript
driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
time.sleep(2)

# %%
for elemento in driver.find_elements_by_tag_name('li'):
    print(elemento.get_attribute('data-slug'))

# %%
# scroll , codigo javascript
driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
time.sleep(2)

# %%
for elemento in driver.find_elements_by_tag_name('li'):
    print(elemento.get_attribute('data-slug'))

# %%
urlbase = 'https://nomadlist.com/'
ciudades = ["Madrid", "Paris", "Amsterdam"]
for i in ciudades:
    driver.get(urlbase + i)

# %%
city=[]
ct=1
while True:
    try:
        city.append(driver.find_element_by_xpath(f'/html/body/div[8]/ul/li[{ct}]/span[1]').text)
        ct +=1
    except:
        break
print(city)

# %%
continente=driver.find_element_by_xpath('/html/body/div[8]/div[2]/div[8]/div[1]/span')                          
continente.click()

# %%
#volver_cont=driver.find_element_by_xpath('/html/body/div[8]/div[2]/div[8]/div[1]/img')
#volver_cont.click()

# %%
import time

time.sleep(2)

for i in range(1,7):
    continente=driver.find_element_by_xpath(f'/html/body/div[8]/div[2]/div[8]/div[{i}]/span')
    continente.click() 
    volver_cont=driver.find_element_by_xpath('/html/body/div[8]/div[2]/div[8]/div[1]/img')
    volver_cont.click()

# %%
for i in range(1,7):
    continente=driver.find_element_by_xpath(f'/html/body/div[8]/div[2]/div[8]/div[{i}]/span')
    continente.click()
    
    city=[]
    ct=1
    while True:
        try:
            city.append(driver.find_element_by_xpath(f'/html/body/div[8]/ul/li[{ct}]/span[1]').text)
            ct +=1
        except:
            break
    print(city)

    volver_cont=driver.find_element_by_xpath('/html/body/div[8]/div[2]/div[8]/div[1]/img')    
volver_cont.click()

# %%
score=[]
score_desc=[]
data=1
while True:
    try:
        score.append(driver.find_element_by_xpath(f'/html/body/div[18]/ajaxloaded/div[3]/div[2]/div[5]/div/div[1]/table/tbody/tr[{data}]/td[1]').text)
        score_desc.append(driver.find_element_by_xpath(f'/html/body/div[18]/ajaxloaded/div[3]/div[2]/div[5]/div/div[1]/table/tbody/tr[{data}]/td[2]/div/div').text)
        data +=1
    except:
        break
print(score)
print(score_desc)

# %%
score=driver.find_element_by_xpath(f'/html/body/div[18]/ajaxloaded/div[3]/div[2]/div[5]/div/div[1]/table/tbody/tr[1]/td[1]').text
print(score)

# %%
score_desc=driver.find_element_by_xpath(f'/html/body/div[18]/ajaxloaded/div[3]/div[2]/div[5]/div/div[1]/table/tbody/tr[1]/td[2]').text
score_desc
